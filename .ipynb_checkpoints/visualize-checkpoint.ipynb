# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

# %%
df = pd.read_csv('all_results.csv')
df.head()
# Out:
#    Unnamed: 0               name             algo_name indices  ratingfrac  \
# 0           0  Under 18 excluded  KNNBaseline_item_msd     NaN         1.0
# 1           1  Under 18 excluded                   SVD     NaN         1.0
# 2           2     18-24 excluded  KNNBaseline_item_msd     NaN         1.0
# 3           3     18-24 excluded                   SVD     NaN         1.0
# 4           4     25-34 excluded  KNNBaseline_item_msd     NaN         1.0
#
#    userfrac               Unnamed: 0.1  fit_time_all  \
# 0       0.5  0000_KNNBaseline_item_msd     15.369191
# 1       0.5                   0000_SVD     50.034708
# 2       0.5  0001_KNNBaseline_item_msd     14.830245
# 3       0.5                   0001_SVD     46.507224
# 4       0.5  0002_KNNBaseline_item_msd     12.761534
#
#    fit_time_all-like-boycott  fit_time_boycott           ...            \
# 0                  15.369191         15.369191           ...
# 1                  50.034708         50.034708           ...
# 2                  14.830245         14.830245           ...
# 3                  46.507224         46.507224           ...
# 4                  12.761534         12.761534           ...
#
#    rmse_all  rmse_all-like-boycott  rmse_boycott  rmse_like-boycott  \
# 0  0.887211               1.037459      1.114452           0.975736
# 1  0.876733               1.050087      1.146766           0.973409
# 2  0.897247               0.980092      1.024963           0.932439
# 3  0.887710               0.969206      1.024393           0.907940
# 4  0.905881               0.929651      0.979513           0.881714
#
#    rmse_non-boycott  test_times_all  test_times_all-like-boycott  \
# 0          0.884181       72.178317                   147.016764
# 1          0.873110        5.351329                    13.862198
# 2          0.883220       67.848187                   145.769697
# 3          0.872343        8.074041                    18.028050
# 4          0.887886       67.996376                   169.768699
#
#    test_times_boycott  test_times_like-boycott  test_times_non-boycott
# 0          145.116230               146.157918              143.804212
# 1           13.738694                13.788180               12.382417
# 2          134.199337               139.798115              132.662584
# 3           16.748750                17.024271               14.578683
# 4          135.248222               151.481311              132.072707
#
# [5 rows x 195 columns]

# %%
samples_df = df[df.name.str.contains('sample')]
samples_df.head()
# Out:
#      Unnamed: 0           name             algo_name     indices  ratingfrac  \
# 264           0  1 user sample  KNNBaseline_item_msd  251-to-500         1.0
# 265           1  1 user sample                   SVD  251-to-500         1.0
# 266           2  1 user sample  KNNBaseline_item_msd  251-to-500         1.0
# 267           3  1 user sample                   SVD  251-to-500         1.0
# 268           4  1 user sample  KNNBaseline_item_msd  251-to-500         1.0
#
#      userfrac               Unnamed: 0.1  fit_time_all  \
# 264       1.0  0000_KNNBaseline_item_msd     26.288869
# 265       1.0                   0000_SVD     77.254085
# 266       1.0  0001_KNNBaseline_item_msd     24.866848
# 267       1.0                   0001_SVD     75.730098
# 268       1.0  0002_KNNBaseline_item_msd     24.796413
#
#      fit_time_all-like-boycott  fit_time_boycott           ...            \
# 264                  26.288869         26.288869           ...
# 265                  77.254085         77.254085           ...
# 266                  24.866848         24.866848           ...
# 267                  75.730098         75.730098           ...
# 268                  24.796413         24.796413           ...
#
#      rmse_all  rmse_all-like-boycott  rmse_boycott  rmse_like-boycott  \
# 264  0.885193               0.910631      0.910631                NaN
# 265  0.873856               0.911339      0.911339                NaN
# 266  0.885336               0.837813      0.837813                NaN
# 267  0.873730               0.865301      0.865301                NaN
# 268  0.885275               0.595576      0.595576                NaN
#
#      rmse_non-boycott  test_times_all  test_times_all-like-boycott  \
# 264          0.885191      119.741490                   239.433852
# 265          0.873853       25.991666                    50.700684
# 266          0.885337      119.285849                   237.998275
# 267          0.873729       26.786353                    49.340827
# 268          0.885340      119.889587                   239.538891
#
#      test_times_boycott  test_times_like-boycott  test_times_non-boycott
# 264          239.432995                      NaN              237.743915
# 265           50.699503                      NaN               48.803505
# 266          237.997447                      NaN              236.306477
# 267           49.339908                      NaN               47.432520
# 268          239.537447                      NaN              237.819864
#
# [5 rows x 195 columns]

# %%
list(samples_df.columns.values)
# Out:
# ['Unnamed: 0',
#  'name',
#  'algo_name',
#  'indices',
#  'ratingfrac',
#  'userfrac',
#  'Unnamed: 0.1',
#  'fit_time_all',
#  'fit_time_all-like-boycott',
#  'fit_time_boycott',
#  'fit_time_like-boycott',
#  'fit_time_non-boycott',
#  'increase_mae_all',
#  'increase_mae_all-like-boycott',
#  'increase_mae_boycott',
#  'increase_mae_like-boycott',
#  'increase_mae_non-boycott',
#  'increase_ndcg10_all',
#  'increase_ndcg10_all-like-boycott',
#  'increase_ndcg10_boycott',
#  'increase_ndcg10_like-boycott',
#  'increase_ndcg10_non-boycott',
#  'increase_ndcg5_all',
#  'increase_ndcg5_all-like-boycott',
#  'increase_ndcg5_boycott',
#  'increase_ndcg5_like-boycott',
#  'increase_ndcg5_non-boycott',
#  'increase_ndcgfull_all',
#  'increase_ndcgfull_all-like-boycott',
#  'increase_ndcgfull_boycott',
#  'increase_ndcgfull_like-boycott',
#  'increase_ndcgfull_non-boycott',
#  'increase_prec10t4_all',
#  'increase_prec10t4_all-like-boycott',
#  'increase_prec10t4_boycott',
#  'increase_prec10t4_like-boycott',
#  'increase_prec10t4_non-boycott',
#  'increase_prec5t4_all',
#  'increase_prec5t4_all-like-boycott',
#  'increase_prec5t4_boycott',
#  'increase_prec5t4_like-boycott',
#  'increase_prec5t4_non-boycott',
#  'increase_rec10t4_all',
#  'increase_rec10t4_all-like-boycott',
#  'increase_rec10t4_boycott',
#  'increase_rec10t4_like-boycott',
#  'increase_rec10t4_non-boycott',
#  'increase_rec5t4_all',
#  'increase_rec5t4_all-like-boycott',
#  'increase_rec5t4_boycott',
#  'increase_rec5t4_like-boycott',
#  'increase_rec5t4_non-boycott',
#  'increase_rmse_all',
#  'increase_rmse_all-like-boycott',
#  'increase_rmse_boycott',
#  'increase_rmse_like-boycott',
#  'increase_rmse_non-boycott',
#  'mae_all',
#  'mae_all-like-boycott',
#  'mae_boycott',
#  'mae_like-boycott',
#  'mae_non-boycott',
#  'ndcg10_all',
#  'ndcg10_all-like-boycott',
#  'ndcg10_boycott',
#  'ndcg10_frac_all',
#  'ndcg10_frac_all-like-boycott',
#  'ndcg10_frac_boycott',
#  'ndcg10_frac_like-boycott',
#  'ndcg10_frac_non-boycott',
#  'ndcg10_like-boycott',
#  'ndcg10_non-boycott',
#  'ndcg5_all',
#  'ndcg5_all-like-boycott',
#  'ndcg5_boycott',
#  'ndcg5_frac_all',
#  'ndcg5_frac_all-like-boycott',
#  'ndcg5_frac_boycott',
#  'ndcg5_frac_like-boycott',
#  'ndcg5_frac_non-boycott',
#  'ndcg5_like-boycott',
#  'ndcg5_non-boycott',
#  'ndcgfull_all',
#  'ndcgfull_all-like-boycott',
#  'ndcgfull_boycott',
#  'ndcgfull_frac_all',
#  'ndcgfull_frac_all-like-boycott',
#  'ndcgfull_frac_boycott',
#  'ndcgfull_frac_like-boycott',
#  'ndcgfull_frac_non-boycott',
#  'ndcgfull_like-boycott',
#  'ndcgfull_non-boycott',
#  'num_movies',
#  'num_ratings',
#  'num_tested_all',
#  'num_tested_all-like-boycott',
#  'num_tested_boycott',
#  'num_tested_like-boycott',
#  'num_tested_non-boycott',
#  'num_users',
#  'percent_increase_mae_all',
#  'percent_increase_mae_all-like-boycott',
#  'percent_increase_mae_boycott',
#  'percent_increase_mae_like-boycott',
#  'percent_increase_mae_non-boycott',
#  'percent_increase_ndcg10_all',
#  'percent_increase_ndcg10_all-like-boycott',
#  'percent_increase_ndcg10_boycott',
#  'percent_increase_ndcg10_like-boycott',
#  'percent_increase_ndcg10_non-boycott',
#  'percent_increase_ndcg5_all',
#  'percent_increase_ndcg5_all-like-boycott',
#  'percent_increase_ndcg5_boycott',
#  'percent_increase_ndcg5_like-boycott',
#  'percent_increase_ndcg5_non-boycott',
#  'percent_increase_ndcgfull_all',
#  'percent_increase_ndcgfull_all-like-boycott',
#  'percent_increase_ndcgfull_boycott',
#  'percent_increase_ndcgfull_like-boycott',
#  'percent_increase_ndcgfull_non-boycott',
#  'percent_increase_prec10t4_all',
#  'percent_increase_prec10t4_all-like-boycott',
#  'percent_increase_prec10t4_boycott',
#  'percent_increase_prec10t4_like-boycott',
#  'percent_increase_prec10t4_non-boycott',
#  'percent_increase_prec5t4_all',
#  'percent_increase_prec5t4_all-like-boycott',
#  'percent_increase_prec5t4_boycott',
#  'percent_increase_prec5t4_like-boycott',
#  'percent_increase_prec5t4_non-boycott',
#  'percent_increase_rec10t4_all',
#  'percent_increase_rec10t4_all-like-boycott',
#  'percent_increase_rec10t4_boycott',
#  'percent_increase_rec10t4_like-boycott',
#  'percent_increase_rec10t4_non-boycott',
#  'percent_increase_rec5t4_all',
#  'percent_increase_rec5t4_all-like-boycott',
#  'percent_increase_rec5t4_boycott',
#  'percent_increase_rec5t4_like-boycott',
#  'percent_increase_rec5t4_non-boycott',
#  'percent_increase_rmse_all',
#  'percent_increase_rmse_all-like-boycott',
#  'percent_increase_rmse_boycott',
#  'percent_increase_rmse_like-boycott',
#  'percent_increase_rmse_non-boycott',
#  'prec10t4_all',
#  'prec10t4_all-like-boycott',
#  'prec10t4_boycott',
#  'prec10t4_frac_all',
#  'prec10t4_frac_all-like-boycott',
#  'prec10t4_frac_boycott',
#  'prec10t4_frac_like-boycott',
#  'prec10t4_frac_non-boycott',
#  'prec10t4_like-boycott',
#  'prec10t4_non-boycott',
#  'prec5t4_all',
#  'prec5t4_all-like-boycott',
#  'prec5t4_boycott',
#  'prec5t4_frac_all',
#  'prec5t4_frac_all-like-boycott',
#  'prec5t4_frac_boycott',
#  'prec5t4_frac_like-boycott',
#  'prec5t4_frac_non-boycott',
#  'prec5t4_like-boycott',
#  'prec5t4_non-boycott',
#  'rec10t4_all',
#  'rec10t4_all-like-boycott',
#  'rec10t4_boycott',
#  'rec10t4_frac_all',
#  'rec10t4_frac_all-like-boycott',
#  'rec10t4_frac_boycott',
#  'rec10t4_frac_like-boycott',
#  'rec10t4_frac_non-boycott',
#  'rec10t4_like-boycott',
#  'rec10t4_non-boycott',
#  'rec5t4_all',
#  'rec5t4_all-like-boycott',
#  'rec5t4_boycott',
#  'rec5t4_frac_all',
#  'rec5t4_frac_all-like-boycott',
#  'rec5t4_frac_boycott',
#  'rec5t4_frac_like-boycott',
#  'rec5t4_frac_non-boycott',
#  'rec5t4_like-boycott',
#  'rec5t4_non-boycott',
#  'rmse_all',
#  'rmse_all-like-boycott',
#  'rmse_boycott',
#  'rmse_like-boycott',
#  'rmse_non-boycott',
#  'test_times_all',
#  'test_times_all-like-boycott',
#  'test_times_boycott',
#  'test_times_like-boycott',
#  'test_times_non-boycott']

# %%
id_vars = ['name','algo_name', 'indices', 'ratingfrac', 'userfrac']
metrics = ['rmse', 'ndcg10', 'prec10']

# %%
def select_cols(cols, metrics, groups, percents):
    """ rename?"""
    increase_cols = [
        x for x in cols if any(metric in x for metric in metrics)
    ]
    increase_cols = [
        x for x in increase_cols if any(group == x.split('_')[-1] for group in groups)
    ]
    if percents:
        increase_cols = [x for x in increase_cols if 'percent' in x]
    else:
        increase_cols = [x for x in increase_cols if 'percent' not in x]
    return increase_cols

# %%
# grouped factor plot
def plot1(df, metrics, groups, percents=False):
    increase_cols = select_cols(list(df.columns.values), metrics, groups, percents)
    longform = df[increase_cols + id_vars].melt(
        id_vars = id_vars,
        var_name='increase_type'
    )
    longform = longform.assign(
        metric=[x.split('_')[-2] for x in longform.increase_type]
    )
    longform = longform.assign(
        group=[x.split('_')[-1] for x in longform.increase_type]
    )
    print(longform.head())
    names = list(set(df.name))
    names = sorted(names, key = lambda x: int(''.join([s for s in x.split() if s.isdigit()])))
    print(names)
    g = sns.factorplot(
        x="name", y="value", hue="group", data=longform,
        size=6, kind="point", col='algo_name', row='metric',
        # xticks=[1,2,3,4,5,6,7,8],
        order=names
    )
    if percents:
        g.set_ylabels("percent increase")
    else:
        g.set_ylabels("increase")
    g.set_xticklabels(["0.01%", "0.05%", "0.1%", "0.5%", "1%", "5%", "10%", "50%",])
    g.set_xlabels('Percent of Users')
    return g

# %%
g = plot1(
    samples_df,
    metrics=metrics,
    percents=True,
    groups=['non-boycott', 'all',]
)
plt.show()
# Out:
#             name             algo_name     indices  ratingfrac  userfrac  \
# 0  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 1  1 user sample                   SVD  251-to-500         1.0       1.0
# 2  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 3  1 user sample                   SVD  251-to-500         1.0       1.0
# 4  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
#
#                  increase_type     value  metric group
# 0  percent_increase_ndcg10_all  0.048378  ndcg10   all
# 1  percent_increase_ndcg10_all  0.229382  ndcg10   all
# 2  percent_increase_ndcg10_all  0.004556  ndcg10   all
# 3  percent_increase_ndcg10_all  0.281903  ndcg10   all
# 4  percent_increase_ndcg10_all  0.070724  ndcg10   all
# ['1 user sample', '3 user sample', '6 user sample', '30 user sample', '60 user sample', '302 user sample', '604 user sample', '3020 user sample']

# %%
g = plot1(
    samples_df,
    metrics=['rmse', 'ndcg', 'prec'],
    percents=False,
    groups=['non-boycott', 'all',]
)
plt.show()
# Out:
#             name             algo_name     indices  ratingfrac  userfrac  \
# 0  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 1  1 user sample                   SVD  251-to-500         1.0       1.0
# 2  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 3  1 user sample                   SVD  251-to-500         1.0       1.0
# 4  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
#
#          increase_type     value  metric group
# 0  increase_ndcg10_all  0.000383  ndcg10   all
# 1  increase_ndcg10_all  0.001815  ndcg10   all
# 2  increase_ndcg10_all  0.000036  ndcg10   all
# 3  increase_ndcg10_all  0.002231  ndcg10   all
# 4  increase_ndcg10_all  0.000560  ndcg10   all
# ['1 user sample', '3 user sample', '6 user sample', '30 user sample', '60 user sample', '302 user sample', '604 user sample', '3020 user sample']

# %%
# for a in ['KNNBaseline_item_msd', 'SVD']:
#     plot1(
#         samples_df[samples_df.algo_name == a],
#         metric='ndcg5',
#         percents=True,
#         groups=['_boycott', '_non-boycott'])
# plt.show()

# %%
organized_df = df[~df.name.str.contains('sample')]
list(set(organized_df.name))
# Out:
# ['users from state US_CA excluded',
#  'farmer excluded',
#  'users from state US_DC excluded',
#  'users from state US_NC excluded',
#  'K-12 student excluded',
#  'users from state US_WA excluded',
#  'Fans of Animation excluded using threshold 4',
#  'Fans of Western excluded using threshold 4',
#  'users from state US_MT excluded',
#  'programmer excluded',
#  'users from state US_KY excluded',
#  'Fans of Romance excluded using threshold 4',
#  '56+ excluded',
#  'users from state US_FL excluded',
#  'users from state US_NH excluded',
#  'users from state US_LA excluded',
#  'Fans of Film-Noir excluded using threshold 4',
#  'doctor/health care excluded',
#  'Top 10% contributors excluded',
#  'other excluded',
#  'tradesman/craftsman excluded',
#  'users from state US_MS excluded',
#  'users from state US_TN excluded',
#  'users from state US_IA excluded',
#  'artist excluded',
#  'users from state US_nan excluded',
#  'users from state US_NM excluded',
#  'female users excluded',
#  'users from state US_GA excluded',
#  'users from state US_UT excluded',
#  'Bottom 10% contributors excluded',
#  'Fans of Fantasy excluded using threshold 4',
#  'users from state US_KS excluded',
#  'self-employed excluded',
#  'users from state US_NV excluded',
#  'Fans of Crime excluded using threshold 4',
#  'users from state US_AR excluded',
#  'retired excluded',
#  'customer service excluded',
#  'users from state US_IN excluded',
#  'users from state US_MN excluded',
#  'users from state US_WY excluded',
#  'users from state US_IL excluded',
#  'users from state US_MO excluded',
#  'users from state US_ME excluded',
#  'users from state US_ID excluded',
#  'users from state US_VT excluded',
#  'lawyer excluded',
#  'Under 18 excluded',
#  'users from state US_SD excluded',
#  'users from state US_CT excluded',
#  'homemaker excluded',
#  'Fans of Comedy excluded using threshold 4',
#  'Fans of War excluded using threshold 4',
#  'users from state US_DE excluded',
#  'users from state US_NY excluded',
#  '25-34 excluded',
#  'academic/educator excluded',
#  'users from state US_CO excluded',
#  '35-44 excluded',
#  'scientist excluded',
#  'users from state US_ND excluded',
#  'users from state US_NE excluded',
#  'users from state US_AK excluded',
#  'Fans of Adventure excluded using threshold 4',
#  'users from state US_VA excluded',
#  'users from state US_AL excluded',
#  'users from state US_WV excluded',
#  'users from state US_OH excluded',
#  'users from state US_OR excluded',
#  'users from state US_RI excluded',
#  "Fans of Children's excluded using threshold 4",
#  'Fans of Thriller excluded using threshold 4',
#  'users from state US_TX excluded',
#  'technician/engineer excluded',
#  'sales/marketing excluded',
#  'users from state US_MD excluded',
#  'users from state US_WI excluded',
#  '50-55 excluded',
#  'Fans of Sci-Fi excluded using threshold 4',
#  'male users excluded',
#  '45-49 excluded',
#  '18-24 excluded',
#  'Fans of Action excluded using threshold 4',
#  'users from state US_MI excluded',
#  'Fans of Mystery excluded using threshold 4',
#  'Fans of Documentary excluded using threshold 4',
#  'users from state US_HI excluded',
#  'unemployed excluded',
#  'executive/managerial excluded',
#  'users from state US_AZ excluded',
#  'users from state US_SC excluded',
#  'users from state US_OK excluded',
#  'clerical/admin excluded',
#  'users from state US_PA excluded',
#  'Fans of Musical excluded using threshold 4',
#  'users from state US_MA excluded',
#  'Fans of Drama excluded using threshold 4',
#  'college/grad student excluded',
#  'Fans of Horror excluded using threshold 4',
#  'writer excluded',
#  'users from state US_NJ excluded']

# %%
def plot2(df, metrics, groups, percents=False):
    increase_cols = select_cols(list(df.columns.values), metrics, groups, percents)
    longform = df[increase_cols + id_vars].melt(
        id_vars = id_vars,
        var_name='increase_type'
    )
    longform = longform.assign(
        metric=[x.split('_')[-2] for x in longform.increase_type]
    )
    longform = longform.assign(
        group=[x.split('_')[-1] for x in longform.increase_type]
    )
    print(longform.head())
    
    g = sns.factorplot(
        x="value", y="name", hue="group", data=longform,
        size=10, kind="point", col='algo_name', row='metric',
        hue_kws={'linestyle': 'None'}
    )

# %%
state_boycotts = organized_df[organized_df.name.str.contains('state')]
plot2(
    state_boycotts,
    metrics=metrics,
    percents=True,
    groups=['non-boycott', 'all', 'boycott', 'like-boycott']
)
plt.show()
# Out:
#                               name             algo_name indices  ratingfrac  \
# 0  users from state US_AZ excluded  KNNBaseline_item_msd     NaN         1.0
# 1  users from state US_AZ excluded                   SVD     NaN         1.0
# 2  users from state US_MI excluded  KNNBaseline_item_msd     NaN         1.0
# 3  users from state US_MI excluded                   SVD     NaN         1.0
# 4  users from state US_NY excluded  KNNBaseline_item_msd     NaN         1.0
#
#    userfrac                increase_type     value  metric group
# 0       0.5  percent_increase_ndcg10_all  0.051018  ndcg10   all
# 1       0.5  percent_increase_ndcg10_all  0.083994  ndcg10   all
# 2       0.5  percent_increase_ndcg10_all -0.042094  ndcg10   all
# 3       0.5  percent_increase_ndcg10_all  0.133330  ndcg10   all
# 4       0.5  percent_increase_ndcg10_all -0.058122  ndcg10   all

# %%
# flag. not a great way to filter the data.
gender_df = organized_df[(organized_df.name.str.contains('male') | organized_df.name.str.contains('female'))]
plot2(
    gender_df,
    metrics=metrics,
    percents=True,
    groups=['non-boycott', 'all', 'boycott', 'like-boycott']
)
plt.show()
# Out:
#                     name             algo_name indices  ratingfrac  userfrac  \
# 0    male users excluded  KNNBaseline_item_msd     NaN         1.0       0.5
# 1    male users excluded                   SVD     NaN         1.0       0.5
# 2  female users excluded  KNNBaseline_item_msd     NaN         1.0       0.5
# 3  female users excluded                   SVD     NaN         1.0       0.5
# 4    male users excluded  KNNBaseline_item_msd     NaN         0.5       1.0
#
#                  increase_type     value  metric group
# 0  percent_increase_ndcg10_all -1.223428  ndcg10   all
# 1  percent_increase_ndcg10_all -1.268019  ndcg10   all
# 2  percent_increase_ndcg10_all -0.371302  ndcg10   all
# 3  percent_increase_ndcg10_all -0.229438  ndcg10   all
# 4  percent_increase_ndcg10_all -1.349792  ndcg10   all

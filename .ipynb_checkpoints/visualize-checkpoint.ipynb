# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
from scipy import stats
from collections import defaultdict

# %%
df = pd.read_csv('all_results.csv')
df.head()
# Out:
#    Unnamed: 0               name             algo_name indices  ratingfrac  \
# 0           0  Under 18 excluded  KNNBaseline_item_msd     NaN         1.0
# 1           1  Under 18 excluded                   SVD     NaN         1.0
# 2           2     18-24 excluded  KNNBaseline_item_msd     NaN         1.0
# 3           3     18-24 excluded                   SVD     NaN         1.0
# 4           4     25-34 excluded  KNNBaseline_item_msd     NaN         1.0
#
#    userfrac               Unnamed: 0.1  fit_time_all  \
# 0       0.5  0000_KNNBaseline_item_msd     15.369191
# 1       0.5                   0000_SVD     50.034708
# 2       0.5  0001_KNNBaseline_item_msd     14.830245
# 3       0.5                   0001_SVD     46.507224
# 4       0.5  0002_KNNBaseline_item_msd     12.761534
#
#    fit_time_all-like-boycott  fit_time_boycott  ...   rmse_all-like-boycott  \
# 0                  15.369191         15.369191  ...                1.037459
# 1                  50.034708         50.034708  ...                1.050087
# 2                  14.830245         14.830245  ...                0.980092
# 3                  46.507224         46.507224  ...                0.969206
# 4                  12.761534         12.761534  ...                0.929651
#
#    rmse_boycott  rmse_like-boycott  rmse_non-boycott  test_times_all  \
# 0      1.114452           0.975736          0.884181       72.178317
# 1      1.146766           0.973409          0.873110        5.351329
# 2      1.024963           0.932439          0.883220       67.848187
# 3      1.024393           0.907940          0.872343        8.074041
# 4      0.979513           0.881714          0.887886       67.996376
#
#    test_times_all-like-boycott  test_times_boycott  test_times_like-boycott  \
# 0                   147.016764          145.116230               146.157918
# 1                    13.862198           13.738694                13.788180
# 2                   145.769697          134.199337               139.798115
# 3                    18.028050           16.748750                17.024271
# 4                   169.768699          135.248222               151.481311
#
#    test_times_non-boycott  type
# 0              143.804212   age
# 1               12.382417   age
# 2              132.662584   age
# 3               14.578683   age
# 4              132.072707   age
#
# [5 rows x 196 columns]

# %%
id_vars = ['name','algo_name', 'indices', 'ratingfrac', 'userfrac']
metrics = ['rmse', 'ndcg10',]
organized_experiments = [
    'gender', 'age', 'state',
    'occupation', 'power', 'genre'
]
algo_names = ['KNNBaseline_item_msd', 'SVD']

# %%
# flag
samples_df = df[df.name.str.contains('sample')]
samples_df.head()

org_df = df[df['type'].isin(organized_experiments)]

# %% [markdown]
# First, let's see how well the # of ratings correlates with error
# This will be an important piece of context for analyzing the experiments.

# %%
algo_to_metric_to_slope = defaultdict(dict)
algo_to_metric_to_intercept = defaultdict(dict)
for algo_name in algo_names:
    filt = org_df[org_df.algo_name == algo_name]
    for metric in metrics:
        key = 'percent_increase_{}_non-boycott'.format(metric)
        sns.jointplot(filt.num_ratings, y=filt[key], kind="reg")
        plt.show()
        slope, intercept, r_value, p_value, std_err = stats.linregress(filt.num_ratings, y=filt[key])
        print(slope, intercept, r_value, p_value)
        algo_to_metric_to_slope[algo_name][metric] = slope
        algo_to_metric_to_intercept[algo_name][metric] = intercept
        
        new_key = key.replace('non-boycott', 'expected')
        kwargs = {new_key: [
            x * slope + intercept for x in list(org_df.num_ratings)
        ]}
        org_df = org_df.assign(**kwargs)
# Out:
# -6.56074930625e-06 6.51133867946 -0.738360522585 7.50631031028e-51
# 3.14433146328e-06 -3.12907928845 0.519681019321 2.52934779193e-21
# -8.53085750426e-06 7.15696496653 -0.816787520804 2.7770473159e-70
# 4.40876705896e-06 -4.13256067093 0.66953020987 8.17702212455e-39

# %%
list(samples_df.columns.values)
# Out:
# ['Unnamed: 0',
#  'name',
#  'algo_name',
#  'indices',
#  'ratingfrac',
#  'userfrac',
#  'Unnamed: 0.1',
#  'fit_time_all',
#  'fit_time_all-like-boycott',
#  'fit_time_boycott',
#  'fit_time_like-boycott',
#  'fit_time_non-boycott',
#  'increase_mae_all',
#  'increase_mae_all-like-boycott',
#  'increase_mae_boycott',
#  'increase_mae_like-boycott',
#  'increase_mae_non-boycott',
#  'increase_ndcg10_all',
#  'increase_ndcg10_all-like-boycott',
#  'increase_ndcg10_boycott',
#  'increase_ndcg10_like-boycott',
#  'increase_ndcg10_non-boycott',
#  'increase_ndcg5_all',
#  'increase_ndcg5_all-like-boycott',
#  'increase_ndcg5_boycott',
#  'increase_ndcg5_like-boycott',
#  'increase_ndcg5_non-boycott',
#  'increase_ndcgfull_all',
#  'increase_ndcgfull_all-like-boycott',
#  'increase_ndcgfull_boycott',
#  'increase_ndcgfull_like-boycott',
#  'increase_ndcgfull_non-boycott',
#  'increase_prec10t4_all',
#  'increase_prec10t4_all-like-boycott',
#  'increase_prec10t4_boycott',
#  'increase_prec10t4_like-boycott',
#  'increase_prec10t4_non-boycott',
#  'increase_prec5t4_all',
#  'increase_prec5t4_all-like-boycott',
#  'increase_prec5t4_boycott',
#  'increase_prec5t4_like-boycott',
#  'increase_prec5t4_non-boycott',
#  'increase_rec10t4_all',
#  'increase_rec10t4_all-like-boycott',
#  'increase_rec10t4_boycott',
#  'increase_rec10t4_like-boycott',
#  'increase_rec10t4_non-boycott',
#  'increase_rec5t4_all',
#  'increase_rec5t4_all-like-boycott',
#  'increase_rec5t4_boycott',
#  'increase_rec5t4_like-boycott',
#  'increase_rec5t4_non-boycott',
#  'increase_rmse_all',
#  'increase_rmse_all-like-boycott',
#  'increase_rmse_boycott',
#  'increase_rmse_like-boycott',
#  'increase_rmse_non-boycott',
#  'mae_all',
#  'mae_all-like-boycott',
#  'mae_boycott',
#  'mae_like-boycott',
#  'mae_non-boycott',
#  'ndcg10_all',
#  'ndcg10_all-like-boycott',
#  'ndcg10_boycott',
#  'ndcg10_frac_all',
#  'ndcg10_frac_all-like-boycott',
#  'ndcg10_frac_boycott',
#  'ndcg10_frac_like-boycott',
#  'ndcg10_frac_non-boycott',
#  'ndcg10_like-boycott',
#  'ndcg10_non-boycott',
#  'ndcg5_all',
#  'ndcg5_all-like-boycott',
#  'ndcg5_boycott',
#  'ndcg5_frac_all',
#  'ndcg5_frac_all-like-boycott',
#  'ndcg5_frac_boycott',
#  'ndcg5_frac_like-boycott',
#  'ndcg5_frac_non-boycott',
#  'ndcg5_like-boycott',
#  'ndcg5_non-boycott',
#  'ndcgfull_all',
#  'ndcgfull_all-like-boycott',
#  'ndcgfull_boycott',
#  'ndcgfull_frac_all',
#  'ndcgfull_frac_all-like-boycott',
#  'ndcgfull_frac_boycott',
#  'ndcgfull_frac_like-boycott',
#  'ndcgfull_frac_non-boycott',
#  'ndcgfull_like-boycott',
#  'ndcgfull_non-boycott',
#  'num_movies',
#  'num_ratings',
#  'num_tested_all',
#  'num_tested_all-like-boycott',
#  'num_tested_boycott',
#  'num_tested_like-boycott',
#  'num_tested_non-boycott',
#  'num_users',
#  'percent_increase_mae_all',
#  'percent_increase_mae_all-like-boycott',
#  'percent_increase_mae_boycott',
#  'percent_increase_mae_like-boycott',
#  'percent_increase_mae_non-boycott',
#  'percent_increase_ndcg10_all',
#  'percent_increase_ndcg10_all-like-boycott',
#  'percent_increase_ndcg10_boycott',
#  'percent_increase_ndcg10_like-boycott',
#  'percent_increase_ndcg10_non-boycott',
#  'percent_increase_ndcg5_all',
#  'percent_increase_ndcg5_all-like-boycott',
#  'percent_increase_ndcg5_boycott',
#  'percent_increase_ndcg5_like-boycott',
#  'percent_increase_ndcg5_non-boycott',
#  'percent_increase_ndcgfull_all',
#  'percent_increase_ndcgfull_all-like-boycott',
#  'percent_increase_ndcgfull_boycott',
#  'percent_increase_ndcgfull_like-boycott',
#  'percent_increase_ndcgfull_non-boycott',
#  'percent_increase_prec10t4_all',
#  'percent_increase_prec10t4_all-like-boycott',
#  'percent_increase_prec10t4_boycott',
#  'percent_increase_prec10t4_like-boycott',
#  'percent_increase_prec10t4_non-boycott',
#  'percent_increase_prec5t4_all',
#  'percent_increase_prec5t4_all-like-boycott',
#  'percent_increase_prec5t4_boycott',
#  'percent_increase_prec5t4_like-boycott',
#  'percent_increase_prec5t4_non-boycott',
#  'percent_increase_rec10t4_all',
#  'percent_increase_rec10t4_all-like-boycott',
#  'percent_increase_rec10t4_boycott',
#  'percent_increase_rec10t4_like-boycott',
#  'percent_increase_rec10t4_non-boycott',
#  'percent_increase_rec5t4_all',
#  'percent_increase_rec5t4_all-like-boycott',
#  'percent_increase_rec5t4_boycott',
#  'percent_increase_rec5t4_like-boycott',
#  'percent_increase_rec5t4_non-boycott',
#  'percent_increase_rmse_all',
#  'percent_increase_rmse_all-like-boycott',
#  'percent_increase_rmse_boycott',
#  'percent_increase_rmse_like-boycott',
#  'percent_increase_rmse_non-boycott',
#  'prec10t4_all',
#  'prec10t4_all-like-boycott',
#  'prec10t4_boycott',
#  'prec10t4_frac_all',
#  'prec10t4_frac_all-like-boycott',
#  'prec10t4_frac_boycott',
#  'prec10t4_frac_like-boycott',
#  'prec10t4_frac_non-boycott',
#  'prec10t4_like-boycott',
#  'prec10t4_non-boycott',
#  'prec5t4_all',
#  'prec5t4_all-like-boycott',
#  'prec5t4_boycott',
#  'prec5t4_frac_all',
#  'prec5t4_frac_all-like-boycott',
#  'prec5t4_frac_boycott',
#  'prec5t4_frac_like-boycott',
#  'prec5t4_frac_non-boycott',
#  'prec5t4_like-boycott',
#  'prec5t4_non-boycott',
#  'rec10t4_all',
#  'rec10t4_all-like-boycott',
#  'rec10t4_boycott',
#  'rec10t4_frac_all',
#  'rec10t4_frac_all-like-boycott',
#  'rec10t4_frac_boycott',
#  'rec10t4_frac_like-boycott',
#  'rec10t4_frac_non-boycott',
#  'rec10t4_like-boycott',
#  'rec10t4_non-boycott',
#  'rec5t4_all',
#  'rec5t4_all-like-boycott',
#  'rec5t4_boycott',
#  'rec5t4_frac_all',
#  'rec5t4_frac_all-like-boycott',
#  'rec5t4_frac_boycott',
#  'rec5t4_frac_like-boycott',
#  'rec5t4_frac_non-boycott',
#  'rec5t4_like-boycott',
#  'rec5t4_non-boycott',
#  'rmse_all',
#  'rmse_all-like-boycott',
#  'rmse_boycott',
#  'rmse_like-boycott',
#  'rmse_non-boycott',
#  'test_times_all',
#  'test_times_all-like-boycott',
#  'test_times_boycott',
#  'test_times_like-boycott',
#  'test_times_non-boycott',
#  'type']

# %%
def select_cols(cols, metrics, groups, percents):
    """ rename?"""
    increase_cols = [
        x for x in cols if (any(metric in x for metric in metrics) and 'increase' in x)
    ]
    increase_cols = [
        x for x in increase_cols if any(group == x.split('_')[-1] for group in groups)
    ]
    if percents:
        increase_cols = [x for x in increase_cols if 'percent' in x]
    else:
        increase_cols = [x for x in increase_cols if 'percent' not in x]
    print(increase_cols)
    return increase_cols

# %%
# grouped factor plot
def plot1(df, metrics, groups, percents=False):
    increase_cols = select_cols(list(df.columns.values), metrics, groups, percents)
    longform = df[increase_cols + id_vars].melt(
        id_vars = id_vars,
        var_name='increase_type'
    )
    longform = longform.assign(
        metric=[x.split('_')[-2] for x in longform.increase_type]
    )
    longform = longform.assign(
        group=[x.split('_')[-1] for x in longform.increase_type]
    )
    print(longform.head())
    names = list(set(df.name))
    names = sorted(names, key = lambda x: int(''.join([s for s in x.split() if s.isdigit()])))
    print(names)
    g = sns.factorplot(
        x="name", y="value", hue="group", data=longform,
        size=6, kind="point", col='algo_name', row='metric',
        # xticks=[1,2,3,4,5,6,7,8],
        order=names
    )
    if percents:
        g.set_ylabels("percent increase")
    else:
        g.set_ylabels("increase")
    g.set_xticklabels(["0.01%", "0.05%", "0.1%", "0.5%", "1%", "5%", "10%", "50%",])
    g.set_xlabels('Percent of Users')
    return g

# %%
g = plot1(
    samples_df,
    metrics=metrics,
    percents=True,
    groups=['non-boycott', 'all',]
)
plt.show()
# Out:
# ['percent_increase_ndcg10_all', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_all', 'percent_increase_rmse_non-boycott']
#             name             algo_name     indices  ratingfrac  userfrac  \
# 0  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 1  1 user sample                   SVD  251-to-500         1.0       1.0
# 2  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 3  1 user sample                   SVD  251-to-500         1.0       1.0
# 4  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
#
#                  increase_type     value  metric group
# 0  percent_increase_ndcg10_all  0.048378  ndcg10   all
# 1  percent_increase_ndcg10_all  0.229382  ndcg10   all
# 2  percent_increase_ndcg10_all  0.004556  ndcg10   all
# 3  percent_increase_ndcg10_all  0.281903  ndcg10   all
# 4  percent_increase_ndcg10_all  0.070724  ndcg10   all
# ['1 user sample', '3 user sample', '6 user sample', '30 user sample', '60 user sample', '302 user sample', '604 user sample', '3020 user sample']

# %%
g = plot1(
    samples_df,
    metrics=['rmse', 'ndcg', 'prec'],
    percents=False,
    groups=['non-boycott', 'all',]
)
plt.show()
# Out:
# ['increase_ndcg10_all', 'increase_ndcg10_non-boycott', 'increase_ndcg5_all', 'increase_ndcg5_non-boycott', 'increase_ndcgfull_all', 'increase_ndcgfull_non-boycott', 'increase_prec10t4_all', 'increase_prec10t4_non-boycott', 'increase_prec5t4_all', 'increase_prec5t4_non-boycott', 'increase_rmse_all', 'increase_rmse_non-boycott']
#             name             algo_name     indices  ratingfrac  userfrac  \
# 0  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 1  1 user sample                   SVD  251-to-500         1.0       1.0
# 2  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
# 3  1 user sample                   SVD  251-to-500         1.0       1.0
# 4  1 user sample  KNNBaseline_item_msd  251-to-500         1.0       1.0
#
#          increase_type     value  metric group
# 0  increase_ndcg10_all  0.000383  ndcg10   all
# 1  increase_ndcg10_all  0.001815  ndcg10   all
# 2  increase_ndcg10_all  0.000036  ndcg10   all
# 3  increase_ndcg10_all  0.002231  ndcg10   all
# 4  increase_ndcg10_all  0.000560  ndcg10   all
# ['1 user sample', '3 user sample', '6 user sample', '30 user sample', '60 user sample', '302 user sample', '604 user sample', '3020 user sample']

# %%
def plot2(df, metrics, groups, percents=False, kind='bar', size=10):
    increase_cols = select_cols(list(df.columns.values), metrics, groups, percents)
    longform = df[increase_cols + id_vars].melt(
        id_vars = id_vars,
        var_name='increase_type'
    )
    longform = longform.assign(
        metric=[x.split('_')[-2] for x in longform.increase_type]
    )
    longform = longform.assign(
        group=[x.split('_')[-1] for x in longform.increase_type]
    )
    g = sns.factorplot(
        x="value", y="name", hue="group", data=longform,
        size=size, kind=kind, col='algo_name', row='metric',
        sharex=False,
        # linestyles='None',
        # capsize=0.1
    )

# %%
state_boycotts = org_df[org_df['type'] == 'state']
gender_boycotts = org_df[org_df['type'] == 'gender']
age_boycotts = org_df[org_df['type'] == 'age']
occupation_boycotts = org_df[org_df['type'] == 'occupation']
power_boycotts = org_df[org_df['type'] == 'power']
genre_boycotts = org_df[org_df['type'] == 'genre']

# %%
def all_users_all_ratings(df):
    return df[(
        (df.userfrac == 1.0) & (df.ratingfrac == 1.0)
    )]

# %%
def half_users(df):
    return df[(
        (df.userfrac == 0.5) & (df.ratingfrac == 1.0)
    )]

# %%
def half_ratings(df):
    return df[(
        (df.userfrac == 1.0) & (df.ratingfrac == 0.5)
    )]

# %%
def plot_all_three_scenarios(df, size=6):
    plot2(
        all_users_all_ratings(df),
        metrics=metrics,
        percents=True,
        groups=['non-boycott', 'expected'],
        size=size
    )
    plot2(
        half_users(df),
        metrics=metrics,
        percents=True,
        groups=['non-boycott', 'like-boycott', 'expected'],
        size=size
    )
    plot2(
        half_ratings(df),
        metrics=metrics,
        percents=True,
        groups=['non-boycott', 'boycott', 'expected'],
        size=size,
    )
    plt.show()

# %%
plot_all_three_scenarios(state_boycotts)
# Out:
# ['percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_like-boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_like-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']

# %%
plot_all_three_scenarios(gender_boycotts)
# Out:
# ['percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_like-boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_like-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']

# %%
plot_all_three_scenarios(power_boycotts, size=5)
# Out:
# ['percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_like-boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_like-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']

# %%
plot_all_three_scenarios(age_boycotts, size=5)
# Out:
# ['percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_like-boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_like-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']

# %%
plot_all_three_scenarios(occupation_boycotts, size=5)
# Out:
# ['percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_like-boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_like-boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']
# ['percent_increase_ndcg10_boycott', 'percent_increase_ndcg10_non-boycott', 'percent_increase_rmse_boycott', 'percent_increase_rmse_non-boycott', 'percent_increase_rmse_expected', 'percent_increase_ndcg10_expected']

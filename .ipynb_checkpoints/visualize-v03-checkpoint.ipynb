# %% [markdown]
# # Visualize Simulated Boycott Results
#
# ## Goals of this notebook
# This notebook includes code for exploring the results of simulated boycotts. It also generates plots (for papers/presentations). This notebook covers 3 broad categories of experiments
#
# 1. MovieLens 1M random boycotts
# 2. MovieLens 1M homogeneous boycotts (e.g. fans of Comedy movies boycott together, people of a single age group boycott together)
# 3. MovieLens 20M random boycotts

# %%
from collections import defaultdict, OrderedDict
import json
from pprint import pprint

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
sns.set_color_codes("dark")

from scipy import stats
from scipy.interpolate import interp1d

# http://files.grouplens.org/datasets/movielens/ml-20m-README.txt

num_users = {
    'ml-20m': 138493,
    'ml-1m': 6040
}
num_ratings = {
    'ml-20m': 20000263,
    'ml-1m': 1000209
}

# %% [markdown]
# First things first: let's load our master data file (a single, aggregated csv).

# %%
df_1m = pd.read_csv('ml-1m_collected/all_results.csv', dtype={'indices': str})
df_1m = df_1m[df_1m.ratingfrac.notna()]

# %%
df_20m = pd.read_csv('ml-20m_collected/all_results.csv', dtype={'indices': str})
df_20m = df_20m[df_20m.ratingfrac.notna()]

# %% [markdown]
# Let's apply transformation that will affect the entire dataframe.
# 1. Calculate the number of users included in each experiment.

# %%
for df, dataset in [
    (df_1m, 'ml-1m',),
    (df_20m, 'ml-20m',),
]:
    # Whoops! Assign doesn't work in a for loop.
#     df = df.assign(num_users_boycotting = [(NUM_USERS - int(x))/NUM_USERS for x in df.num_users])
#     df = df.assign(num_ratings_missing = [NUM_RATINGS - int(x) for x in df.num_ratings])
#     df = df.assign(nrm_rounded = [round(x, -5) for x in df.num_ratings_missing])
    df['num_users_boycotting'] = [(num_users[dataset] - int(x)) / num_users[dataset] for x in df.num_users]
    df['num_ratings_missing'] = [num_ratings[dataset] - int(x) for x in df.num_ratings]
    df['nrm_rounded'] = [round(x, -5) for x in df.num_ratings_missing]

    # drop columns we're not going to use.
    drops = [
        #'tail',
        # 'vanilla',
    ]
    for column in df.columns.values:
        for drop in drops:
            if drop in column:
                df = df.drop(column, axis=1)
print(df_1m.columns.values)
# Out:
# ['Unnamed: 0' 'name' 'algo_name' 'indices' 'ratingfrac' 'userfrac'
#  'Unnamed: 0.1' 'fit_time_all' 'fit_time_all-like-boycott'
#  'fit_time_boycott' 'fit_time_like-boycott' 'fit_time_non-boycott'
#  'increase_mae_all' 'increase_mae_all-like-boycott' 'increase_mae_boycott'
#  'increase_mae_like-boycott' 'increase_mae_non-boycott'
#  'increase_ndcg10_all' 'increase_ndcg10_all-like-boycott'
#  'increase_ndcg10_boycott' 'increase_ndcg10_like-boycott'
#  'increase_ndcg10_non-boycott' 'increase_ndcg5_all'
#  'increase_ndcg5_all-like-boycott' 'increase_ndcg5_boycott'
#  'increase_ndcg5_like-boycott' 'increase_ndcg5_non-boycott'
#  'increase_ndcgfull_all' 'increase_ndcgfull_all-like-boycott'
#  'increase_ndcgfull_boycott' 'increase_ndcgfull_like-boycott'
#  'increase_ndcgfull_non-boycott' 'increase_prec10t4_all'
#  'increase_prec10t4_all-like-boycott' 'increase_prec10t4_boycott'
#  'increase_prec10t4_like-boycott' 'increase_prec10t4_non-boycott'
#  'increase_prec5t4_all' 'increase_prec5t4_all-like-boycott'
#  'increase_prec5t4_boycott' 'increase_prec5t4_like-boycott'
#  'increase_prec5t4_non-boycott' 'increase_rec10t4_all'
#  'increase_rec10t4_all-like-boycott' 'increase_rec10t4_boycott'
#  'increase_rec10t4_like-boycott' 'increase_rec10t4_non-boycott'
#  'increase_rec5t4_all' 'increase_rec5t4_all-like-boycott'
#  'increase_rec5t4_boycott' 'increase_rec5t4_like-boycott'
#  'increase_rec5t4_non-boycott' 'increase_rmse_all'
#  'increase_rmse_all-like-boycott' 'increase_rmse_boycott'
#  'increase_rmse_like-boycott' 'increase_rmse_non-boycott'
#  'increase_tailndcg10_all' 'increase_tailndcg10_all-like-boycott'
#  'increase_tailndcg10_boycott' 'increase_tailndcg10_like-boycott'
#  'increase_tailndcg10_non-boycott' 'increase_tailndcg5_all'
#  'increase_tailndcg5_all-like-boycott' 'increase_tailndcg5_boycott'
#  'increase_tailndcg5_like-boycott' 'increase_tailndcg5_non-boycott'
#  'increase_tailndcgfull_all' 'increase_tailndcgfull_all-like-boycott'
#  'increase_tailndcgfull_boycott' 'increase_tailndcgfull_like-boycott'
#  'increase_tailndcgfull_non-boycott' 'increase_tailprec10t4_all'
#  'increase_tailprec10t4_all-like-boycott' 'increase_tailprec10t4_boycott'
#  'increase_tailprec10t4_like-boycott' 'increase_tailprec10t4_non-boycott'
#  'increase_tailprec5t4_all' 'increase_tailprec5t4_all-like-boycott'
#  'increase_tailprec5t4_boycott' 'increase_tailprec5t4_like-boycott'
#  'increase_tailprec5t4_non-boycott' 'increase_tailrec10t4_all'
#  'increase_tailrec10t4_all-like-boycott' 'increase_tailrec10t4_boycott'
#  'increase_tailrec10t4_like-boycott' 'increase_tailrec10t4_non-boycott'
#  'increase_tailrec5t4_all' 'increase_tailrec5t4_all-like-boycott'
#  'increase_tailrec5t4_boycott' 'increase_tailrec5t4_like-boycott'
#  'increase_tailrec5t4_non-boycott' 'mae_all' 'mae_all-like-boycott'
#  'mae_boycott' 'mae_like-boycott' 'mae_non-boycott' 'ndcg10_all'
#  'ndcg10_all-like-boycott' 'ndcg10_boycott' 'ndcg10_frac_all'
#  'ndcg10_frac_all-like-boycott' 'ndcg10_frac_boycott'
#  'ndcg10_frac_like-boycott' 'ndcg10_frac_non-boycott'
#  'ndcg10_like-boycott' 'ndcg10_non-boycott' 'ndcg5_all'
#  'ndcg5_all-like-boycott' 'ndcg5_boycott' 'ndcg5_frac_all'
#  'ndcg5_frac_all-like-boycott' 'ndcg5_frac_boycott'
#  'ndcg5_frac_like-boycott' 'ndcg5_frac_non-boycott' 'ndcg5_like-boycott'
#  'ndcg5_non-boycott' 'ndcgfull_all' 'ndcgfull_all-like-boycott'
#  'ndcgfull_boycott' 'ndcgfull_frac_all' 'ndcgfull_frac_all-like-boycott'
#  'ndcgfull_frac_boycott' 'ndcgfull_frac_like-boycott'
#  'ndcgfull_frac_non-boycott' 'ndcgfull_like-boycott'
#  'ndcgfull_non-boycott' 'num_movies' 'num_ratings' 'num_tested_all'
#  'num_tested_all-like-boycott' 'num_tested_boycott'
#  'num_tested_like-boycott' 'num_tested_non-boycott' 'num_users'
#  'percent_increase_mae_all' 'percent_increase_mae_all-like-boycott'
#  'percent_increase_mae_boycott' 'percent_increase_mae_like-boycott'
#  'percent_increase_mae_non-boycott' 'percent_increase_ndcg10_all'
#  'percent_increase_ndcg10_all-like-boycott'
#  'percent_increase_ndcg10_boycott' 'percent_increase_ndcg10_like-boycott'
#  'percent_increase_ndcg10_non-boycott' 'percent_increase_ndcg5_all'
#  'percent_increase_ndcg5_all-like-boycott'
#  'percent_increase_ndcg5_boycott' 'percent_increase_ndcg5_like-boycott'
#  'percent_increase_ndcg5_non-boycott' 'percent_increase_ndcgfull_all'
#  'percent_increase_ndcgfull_all-like-boycott'
#  'percent_increase_ndcgfull_boycott'
#  'percent_increase_ndcgfull_like-boycott'
#  'percent_increase_ndcgfull_non-boycott' 'percent_increase_prec10t4_all'
#  'percent_increase_prec10t4_all-like-boycott'
#  'percent_increase_prec10t4_boycott'
#  'percent_increase_prec10t4_like-boycott'
#  'percent_increase_prec10t4_non-boycott' 'percent_increase_prec5t4_all'
#  'percent_increase_prec5t4_all-like-boycott'
#  'percent_increase_prec5t4_boycott'
#  'percent_increase_prec5t4_like-boycott'
#  'percent_increase_prec5t4_non-boycott' 'percent_increase_rec10t4_all'
#  'percent_increase_rec10t4_all-like-boycott'
#  'percent_increase_rec10t4_boycott'
#  'percent_increase_rec10t4_like-boycott'
#  'percent_increase_rec10t4_non-boycott' 'percent_increase_rec5t4_all'
#  'percent_increase_rec5t4_all-like-boycott'
#  'percent_increase_rec5t4_boycott' 'percent_increase_rec5t4_like-boycott'
#  'percent_increase_rec5t4_non-boycott' 'percent_increase_rmse_all'
#  'percent_increase_rmse_all-like-boycott' 'percent_increase_rmse_boycott'
#  'percent_increase_rmse_like-boycott' 'percent_increase_rmse_non-boycott'
#  'percent_increase_tailndcg10_all'
#  'percent_increase_tailndcg10_all-like-boycott'
#  'percent_increase_tailndcg10_boycott'
#  'percent_increase_tailndcg10_like-boycott'
#  'percent_increase_tailndcg10_non-boycott'
#  'percent_increase_tailndcg5_all'
#  'percent_increase_tailndcg5_all-like-boycott'
#  'percent_increase_tailndcg5_boycott'
#  'percent_increase_tailndcg5_like-boycott'
#  'percent_increase_tailndcg5_non-boycott'
#  'percent_increase_tailndcgfull_all'
#  'percent_increase_tailndcgfull_all-like-boycott'
#  'percent_increase_tailndcgfull_boycott'
#  'percent_increase_tailndcgfull_like-boycott'
#  'percent_increase_tailndcgfull_non-boycott'
#  'percent_increase_tailprec10t4_all'
#  'percent_increase_tailprec10t4_all-like-boycott'
#  'percent_increase_tailprec10t4_boycott'
#  'percent_increase_tailprec10t4_like-boycott'
#  'percent_increase_tailprec10t4_non-boycott'
#  'percent_increase_tailprec5t4_all'
#  'percent_increase_tailprec5t4_all-like-boycott'
#  'percent_increase_tailprec5t4_boycott'
#  'percent_increase_tailprec5t4_like-boycott'
#  'percent_increase_tailprec5t4_non-boycott'
#  'percent_increase_tailrec10t4_all'
#  'percent_increase_tailrec10t4_all-like-boycott'
#  'percent_increase_tailrec10t4_boycott'
#  'percent_increase_tailrec10t4_like-boycott'
#  'percent_increase_tailrec10t4_non-boycott'
#  'percent_increase_tailrec5t4_all'
#  'percent_increase_tailrec5t4_all-like-boycott'
#  'percent_increase_tailrec5t4_boycott'
#  'percent_increase_tailrec5t4_like-boycott'
#  'percent_increase_tailrec5t4_non-boycott' 'prec10t4_all'
#  'prec10t4_all-like-boycott' 'prec10t4_boycott' 'prec10t4_frac_all'
#  'prec10t4_frac_all-like-boycott' 'prec10t4_frac_boycott'
#  'prec10t4_frac_like-boycott' 'prec10t4_frac_non-boycott'
#  'prec10t4_like-boycott' 'prec10t4_non-boycott' 'prec5t4_all'
#  'prec5t4_all-like-boycott' 'prec5t4_boycott' 'prec5t4_frac_all'
#  'prec5t4_frac_all-like-boycott' 'prec5t4_frac_boycott'
#  'prec5t4_frac_like-boycott' 'prec5t4_frac_non-boycott'
#  'prec5t4_like-boycott' 'prec5t4_non-boycott' 'rec10t4_all'
#  'rec10t4_all-like-boycott' 'rec10t4_boycott' 'rec10t4_frac_all'
#  'rec10t4_frac_all-like-boycott' 'rec10t4_frac_boycott'
#  'rec10t4_frac_like-boycott' 'rec10t4_frac_non-boycott'
#  'rec10t4_like-boycott' 'rec10t4_non-boycott' 'rec5t4_all'
#  'rec5t4_all-like-boycott' 'rec5t4_boycott' 'rec5t4_frac_all'
#  'rec5t4_frac_all-like-boycott' 'rec5t4_frac_boycott'
#  'rec5t4_frac_like-boycott' 'rec5t4_frac_non-boycott'
#  'rec5t4_like-boycott' 'rec5t4_non-boycott' 'rmse_all'
#  'rmse_all-like-boycott' 'rmse_boycott' 'rmse_like-boycott'
#  'rmse_non-boycott' 'standards_fit_time_all'
#  'standards_fit_time_all-like-boycott' 'standards_fit_time_boycott'
#  'standards_fit_time_like-boycott' 'standards_fit_time_non-boycott'
#  'standards_mae_all' 'standards_mae_all-like-boycott'
#  'standards_mae_boycott' 'standards_mae_like-boycott'
#  'standards_mae_non-boycott' 'standards_ndcg10_all'
#  'standards_ndcg10_all-like-boycott' 'standards_ndcg10_boycott'
#  'standards_ndcg10_frac_all' 'standards_ndcg10_frac_all-like-boycott'
#  'standards_ndcg10_frac_boycott' 'standards_ndcg10_frac_like-boycott'
#  'standards_ndcg10_frac_non-boycott' 'standards_ndcg10_like-boycott'
#  'standards_ndcg10_non-boycott' 'standards_ndcg5_all'
#  'standards_ndcg5_all-like-boycott' 'standards_ndcg5_boycott'
#  'standards_ndcg5_frac_all' 'standards_ndcg5_frac_all-like-boycott'
#  'standards_ndcg5_frac_boycott' 'standards_ndcg5_frac_like-boycott'
#  'standards_ndcg5_frac_non-boycott' 'standards_ndcg5_like-boycott'
#  'standards_ndcg5_non-boycott' 'standards_ndcgfull_all'
#  'standards_ndcgfull_all-like-boycott' 'standards_ndcgfull_boycott'
#  'standards_ndcgfull_frac_all' 'standards_ndcgfull_frac_all-like-boycott'
#  'standards_ndcgfull_frac_boycott' 'standards_ndcgfull_frac_like-boycott'
#  'standards_ndcgfull_frac_non-boycott' 'standards_ndcgfull_like-boycott'
#  'standards_ndcgfull_non-boycott' 'standards_num_tested_all'
#  'standards_num_tested_all-like-boycott' 'standards_num_tested_boycott'
#  'standards_num_tested_like-boycott' 'standards_num_tested_non-boycott'
#  'standards_prec10t4_all' 'standards_prec10t4_all-like-boycott'
#  'standards_prec10t4_boycott' 'standards_prec10t4_frac_all'
#  'standards_prec10t4_frac_all-like-boycott'
#  'standards_prec10t4_frac_boycott' 'standards_prec10t4_frac_like-boycott'
#  'standards_prec10t4_frac_non-boycott' 'standards_prec10t4_like-boycott'
#  'standards_prec10t4_non-boycott' 'standards_prec5t4_all'
#  'standards_prec5t4_all-like-boycott' 'standards_prec5t4_boycott'
#  'standards_prec5t4_frac_all' 'standards_prec5t4_frac_all-like-boycott'
#  'standards_prec5t4_frac_boycott' 'standards_prec5t4_frac_like-boycott'
#  'standards_prec5t4_frac_non-boycott' 'standards_prec5t4_like-boycott'
#  'standards_prec5t4_non-boycott' 'standards_rec10t4_all'
#  'standards_rec10t4_all-like-boycott' 'standards_rec10t4_boycott'
#  'standards_rec10t4_frac_all' 'standards_rec10t4_frac_all-like-boycott'
#  'standards_rec10t4_frac_boycott' 'standards_rec10t4_frac_like-boycott'
#  'standards_rec10t4_frac_non-boycott' 'standards_rec10t4_like-boycott'
#  'standards_rec10t4_non-boycott' 'standards_rec5t4_all'
#  'standards_rec5t4_all-like-boycott' 'standards_rec5t4_boycott'
#  'standards_rec5t4_frac_all' 'standards_rec5t4_frac_all-like-boycott'
#  'standards_rec5t4_frac_boycott' 'standards_rec5t4_frac_like-boycott'
#  'standards_rec5t4_frac_non-boycott' 'standards_rec5t4_like-boycott'
#  'standards_rec5t4_non-boycott' 'standards_rmse_all'
#  'standards_rmse_all-like-boycott' 'standards_rmse_boycott'
#  'standards_rmse_like-boycott' 'standards_rmse_non-boycott'
#  'standards_tailndcg10_all' 'standards_tailndcg10_all-like-boycott'
#  'standards_tailndcg10_boycott' 'standards_tailndcg10_like-boycott'
#  'standards_tailndcg10_non-boycott' 'standards_tailndcg5_all'
#  'standards_tailndcg5_all-like-boycott' 'standards_tailndcg5_boycott'
#  'standards_tailndcg5_like-boycott' 'standards_tailndcg5_non-boycott'
#  'standards_tailndcgfull_all' 'standards_tailndcgfull_all-like-boycott'
#  'standards_tailndcgfull_boycott' 'standards_tailndcgfull_like-boycott'
#  'standards_tailndcgfull_non-boycott' 'standards_tailprec10t4_all'
#  'standards_tailprec10t4_all-like-boycott'
#  'standards_tailprec10t4_boycott' 'standards_tailprec10t4_like-boycott'
#  'standards_tailprec10t4_non-boycott' 'standards_tailprec5t4_all'
#  'standards_tailprec5t4_all-like-boycott' 'standards_tailprec5t4_boycott'
#  'standards_tailprec5t4_like-boycott' 'standards_tailprec5t4_non-boycott'
#  'standards_tailrec10t4_all' 'standards_tailrec10t4_all-like-boycott'
#  'standards_tailrec10t4_boycott' 'standards_tailrec10t4_like-boycott'
#  'standards_tailrec10t4_non-boycott' 'standards_tailrec5t4_all'
#  'standards_tailrec5t4_all-like-boycott' 'standards_tailrec5t4_boycott'
#  'standards_tailrec5t4_like-boycott' 'standards_tailrec5t4_non-boycott'
#  'standards_test_times_all' 'standards_test_times_all-like-boycott'
#  'standards_test_times_boycott' 'standards_test_times_like-boycott'
#  'standards_test_times_non-boycott' 'tailndcg10_all'
#  'tailndcg10_all-like-boycott' 'tailndcg10_boycott'
#  'tailndcg10_like-boycott' 'tailndcg10_non-boycott' 'tailndcg5_all'
#  'tailndcg5_all-like-boycott' 'tailndcg5_boycott' 'tailndcg5_like-boycott'
#  'tailndcg5_non-boycott' 'tailndcgfull_all'
#  'tailndcgfull_all-like-boycott' 'tailndcgfull_boycott'
#  'tailndcgfull_like-boycott' 'tailndcgfull_non-boycott' 'tailprec10t4_all'
#  'tailprec10t4_all-like-boycott' 'tailprec10t4_boycott'
#  'tailprec10t4_like-boycott' 'tailprec10t4_non-boycott' 'tailprec5t4_all'
#  'tailprec5t4_all-like-boycott' 'tailprec5t4_boycott'
#  'tailprec5t4_like-boycott' 'tailprec5t4_non-boycott' 'tailrec10t4_all'
#  'tailrec10t4_all-like-boycott' 'tailrec10t4_boycott'
#  'tailrec10t4_like-boycott' 'tailrec10t4_non-boycott' 'tailrec5t4_all'
#  'tailrec5t4_all-like-boycott' 'tailrec5t4_boycott'
#  'tailrec5t4_like-boycott' 'tailrec5t4_non-boycott' 'test_times_all'
#  'test_times_all-like-boycott' 'test_times_boycott'
#  'test_times_like-boycott' 'test_times_non-boycott' 'type'
#  'num_users_boycotting' 'num_ratings_missing' 'nrm_rounded']

# %% [markdown]
# # EDIT ME
# Define all the lists that can be used throughout. By editing this cell we can easily modify the full notebook.

# %%
id_vars = ['name','algo_name', 'indices', 'ratingfrac', 'userfrac', 'num_ratings', 'num_users', 'num_users_boycotting']
#id_vars = [x for x in id_vars if x in list(df.columns.values)]
metrics = [
    'rmse',
    'ndcg10',
    #'tailndcg10',
    #'ndcg5',
    #'tailndcg5',
    #'ndcgfull',
    #'tailndcgfull',
    #'ndcgfull',
    #'prec10t4',
    #'tailprec10t4',
    #'prec5t4',
    #'tailprec5t4',
]

organized_experiments = [
    'gender', 'state', 'power', 'genre', 'occupation', 'age'
]
algo_names = [
    #'KNNBaseline_item_msd',
    'SVD'
]
standard_algo_names = [
    'SVD', 
    #'GlobalMean', 'GuessThree',
    'MovieMean', 
    'KNNBaseline_item_msd',
    'KNNBasic_user_msd',
    'KNNBasic_item_msd',
]

# %% [markdown]
# ## Load and Organize Standard Results
# For any of our visualizations to be meaningful, we need standard results to compare the boycott results to. These standards let us evaluate "what is the effect of the boycott compared to other algorithms".
#
# In particular, we compare the boycott performance to performance when using very non-personalized algorithms (GlobalMean, MovieMean, GuessThree) and simpler personalized algorithms (user-based KNN, item-based KNN).
#
# Below, we load these results from json files into Python data structures so we can use below when generating plots.

# %%
dataset_to_algo_to_metric_to_altalgo = {}

one_mill_svd = {}
for dataset in [
    'ml-1m',
    'ml-20m',
]:
    standard_results = {}
    algo_to_metric_to_altalgo = defaultdict(lambda: defaultdict(dict))

    for algo_name in standard_algo_names:
        try:
            filename_ratingcv_standards = 'standard_results/{}_ratingcv_standards_for_{}.json'.format(
                dataset, algo_name)
            with open(filename_ratingcv_standards, 'r') as f:
                standard_results[algo_name] = json.load(f)
                if algo_name == 'SVD' and dataset == 'ml-1m':
                    one_mill_svd = standard_results[algo_name]
        except FileNotFoundError:
            print('File not found: {}'.format(filename_ratingcv_standards))
    for main_algo_name in algo_names:
        for metric in metrics:
            goodval = standard_results[main_algo_name].get(metric, 0)
            for st_algo_name in standard_algo_names:
                val = standard_results.get(st_algo_name, {}).get(metric)
                if val:
                    algo_to_metric_to_altalgo[main_algo_name][metric][st_algo_name] = (val - goodval) / goodval * 100 if goodval else 0
                else:
                    algo_to_metric_to_altalgo[main_algo_name][metric][st_algo_name] = 0
            if dataset == 'ml-20m':
                val = one_mill_svd.get(metric)
                if val:
                    algo_to_metric_to_altalgo[main_algo_name][metric]['1M_SVD'] = (val - goodval) / goodval * 100 if goodval else 0
                else:
                    algo_to_metric_to_altalgo[main_algo_name][metric]['1M_SVD'] = 0
            
    dataset_to_algo_to_metric_to_altalgo[dataset] = algo_to_metric_to_altalgo
pprint(dataset_to_algo_to_metric_to_altalgo)
# Out:
# File not found: standard_results/ml-20m_ratingcv_standards_for_KNNBasic_user_msd.json
# {'ml-1m': defaultdict(<function <lambda> at 0x000001C1E2B9C2F0>,
#                       {'SVD': defaultdict(<class 'dict'>,
#                                           {'ndcg10': {'KNNBaseline_item_msd': -0.21579272303199185,
#                                                       'KNNBasic_item_msd': -0.783459813821296,
#                                                       'KNNBasic_user_msd': -1.774069901999796,
#                                                       'MovieMean': -2.527446665665193,
#                                                       'SVD': 0.0},
#                                            'rmse': {'KNNBaseline_item_msd': 1.326125568048003,
#                                                     'KNNBasic_item_msd': 4.626236780474338,
#                                                     'KNNBasic_user_msd': 5.627334338473019,
#                                                     'MovieMean': 12.072697294556987,
#                                                     'SVD': 0.0}})}),
#  'ml-20m': defaultdict(<function <lambda> at 0x000001C1DF1FFD08>,
#                        {'SVD': defaultdict(<class 'dict'>,
#                                            {'ndcg10': {'1M_SVD': -2.3961525421001535,
#                                                        'KNNBaseline_item_msd': -2.545825243372394,
#                                                        'KNNBasic_item_msd': -2.2383269117241746,
#                                                        'KNNBasic_user_msd': 0,
#                                                        'MovieMean': -5.647772312509133,
#                                                        'SVD': 0.0},
#                                             'rmse': {'1M_SVD': 11.166751126528048,
#                                                      'KNNBaseline_item_msd': 4.991087869128467,
#                                                      'KNNBasic_item_msd': 8.197945180278845,
#                                                      'KNNBasic_user_msd': 0,
#                                                      'MovieMean': 19.759535282577247,
#                                                      'SVD': 0.0}})})}

# %% [markdown]
# ## Seperate out our data
# We want to separate the Results dataframes into homogenous vs. heterogenous boycotts.

# %%
samples_df_20m = df_20m[df_20m['type'] == 'sample_users']
print('\n===Heterogenous 20M Boycotts===\n')
print(samples_df_20m.name.value_counts())
samples_df_1m = df_1m[df_1m['type'] == 'sample_users']
print('\n===Heterogenous Boycotts===\n')
print(samples_df_1m.name.value_counts())
org_df = df_1m[df_1m['type'].isin(organized_experiments)]
print('\n===Homogenous Boycotts===\n')
print(org_df.name.value_counts())
# Out:
# ===Heterogenous 20M Boycotts===
#
# 124644 user sample    50
# 27699 user sample     50
# 55397 user sample     50
# 110794 user sample    50
# 83096 user sample     50
# 96945 user sample     50
# 6925 user sample      50
# 137108 user sample    50
# 1385 user sample      50
# 69 user sample        50
# 138 user sample       50
# 692 user sample       50
# 69246 user sample     50
# 14 user sample        50
# 13849 user sample     50
# 41548 user sample     50
# Name: name, dtype: int64
#
# ===Heterogenous Boycotts===
#
# 4832 user sample    250
# 4228 user sample    250
# 30 user sample      250
# 3020 user sample    250
# 3624 user sample    250
# 6 user sample       250
# 302 user sample     250
# 1208 user sample    250
# 3 user sample       250
# 5980 user sample    250
# 60 user sample      250
# 1 user sample       250
# 2416 user sample    250
# 604 user sample     250
# 5436 user sample    250
# 1812 user sample    250
# Name: name, dtype: int64
#
# ===Homogenous Boycotts===
#
# male users excluded                              60
# female users excluded                            60
# users from state US_MI excluded                  50
# users from state US_nan excluded                 50
# 50-55 excluded                                   50
# users from state US_DE excluded                  50
# users from state US_CT excluded                  50
# users from state US_MS excluded                  50
# users from state US_RI excluded                  50
# Fans of Comedy excluded using threshold 4        50
# users from state US_WA excluded                  50
# sales/marketing excluded                         50
# lawyer excluded                                  50
# Fans of Fantasy excluded using threshold 4       50
# users from state US_DC excluded                  50
# users from state US_MD excluded                  50
# Fans of Sci-Fi excluded using threshold 4        50
# Fans of Children's excluded using threshold 4    50
# customer service excluded                        50
# users from state US_NJ excluded                  50
# users from state US_AK excluded                  50
# Fans of Action excluded using threshold 4        50
# users from state US_NY excluded                  50
# homemaker excluded                               50
# 45-49 excluded                                   50
# users from state US_HI excluded                  50
# Under 18 excluded                                50
# users from state US_OR excluded                  50
# users from state US_CO excluded                  50
# Fans of Western excluded using threshold 4       50
#                                                  ..
# users from state US_OH excluded                  50
# academic/educator excluded                       50
# users from state US_GA excluded                  50
# users from state US_VA excluded                  50
# users from state US_SD excluded                  50
# artist excluded                                  50
# users from state US_OK excluded                  50
# users from state US_NV excluded                  50
# users from state US_IA excluded                  50
# Bottom 10% contributors excluded                 50
# users from state US_AZ excluded                  50
# other excluded                                   50
# executive/managerial excluded                    50
# self-employed excluded                           50
# users from state US_TN excluded                  50
# users from state US_WY excluded                  50
# users from state US_MT excluded                  50
# users from state US_SC excluded                  50
# doctor/health care excluded                      50
# users from state US_AL excluded                  50
# users from state US_ND excluded                  50
# users from state US_PA excluded                  50
# Fans of War excluded using threshold 4           50
# users from state US_CA excluded                  50
# users from state US_MN excluded                  50
# college/grad student excluded                    50
# Fans of Mystery excluded using threshold 4       50
# users from state US_NH excluded                  50
# users from state US_ID excluded                  50
# Fans of Drama excluded using threshold 4         50
# Name: name, Length: 102, dtype: int64

# %% [markdown]
# ## Clean up the homogenous boycott "name" columns
# This is helpful because our homogenous boycott plots are going to very cluttered. We want to remove as much text as possible without making the plots too confusing.

# %%
org_df.name = [
    x.replace('excluded', '')
    .replace('users from', '')
#     .replace('US_', '')
#     .replace('state', '')
    .replace('using threshold 4', '')
    .replace('Top 10% contributors', 'power users')
    .strip()
    .lower()
    for x in list(org_df.name)
]
# Out:
# C:\Users\Nick\Anaconda3\lib\site-packages\pandas\core\generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# ## Data Manipulating Helpers
# In the following two cells, we define two functions (select_cols and fill_in_longform) that will help with general purpose manipulating of our result data.

# %%
def select_cols(cols, metrics, groups, percents):
    """
    take a list of cols and filter based on metrics/groups/percents
    
    The returned columns must match all the metrics and groups passed
    if percents is True, return columns with "percent" in the name
    if percents is False return only columns without "percent" in the name
    
    returns a list of cols
    """
    increase_cols = [
        x for x in cols if 'increase' in x and (any(metric == x.split('_')[-2] for metric in metrics))
    ]
    increase_cols = [
        x for x in increase_cols if any(group == x.split('_')[-1] for group in groups)
    ]
    if percents:
        increase_cols = [x for x in increase_cols if 'percent' in x]
    else:
        increase_cols = [x for x in increase_cols if 'percent' not in x]
    return increase_cols

# %%
def fill_in_longform(df):
    """Fill in a longform dataframe with metric, group, and name information"""
    df = df.assign(
        metric=[x.split('_')[-2] for x in df.increase_type]
    )
    df = df.assign(
        group=[x.split('_')[-1] for x in df.increase_type]
    )
    return df

# %%
palette={'all': 'b', 'non-boycott': 'g'}
TITLE = 'Effect of Boycott Size on Recommender Performance'
YLABEL = 'nDCG@10 personalization factor'

# %%
def p_b_curve(
        df, dataset, metrics, groups,
        percents=False, normalize=True,
        reg_plot=False, hue='group', row='metric',
        save=False, show_interp=False,
    ):
    """
    Plots a performance vs. boycott size (P v B) curve
    
    Args:
        df - the dataframe to use for plotting the pb curve
        metrics - which metrics to plot the curve for.
        groups - which groups to include.
          for each metric, 
        percents - show the Y-axis in percent change or raw change. Set this True for percent change.
        normalize - should we normalize the y-axis relative to MovieMean (no personalization)
        reg_plot - ?
        hue - which facet to use to determine hue. default is group
          (each group will appear as a separate (distinctly colored) trajectory on each plot)
        row - which facet to use to split plots into different rows. default is metric.
        save - should we save a PNG file?
        show_interp - include the interpolated function on this plot?
        
    Returns:
        ?
    """
    algo_to_metric_to_altalgo=dataset_to_algo_to_metric_to_altalgo[dataset]
    
    algo_names = list(set(df.algo_name))
    df = df.copy()
    algo_to_metric_to_group_to = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))

    increase_cols = select_cols(list(df.columns.values), metrics, groups, percents)
    increase_cols = [x for x in increase_cols if 'vanilla' not in x]
    if normalize:
        for metric in metrics:
            for algo_name in algo_names:
                movie_val = abs(algo_to_metric_to_altalgo[algo_name][metric]['MovieMean'])
                for increase_col in increase_cols:
                    if increase_col.split('_')[-2] == metric:
                        df.loc[df.algo_name == algo_name, increase_col] /= movie_val
    
    longform = df[increase_cols + id_vars].melt(
        id_vars = id_vars,
        var_name='increase_type'
    )
    longform = fill_in_longform(longform)

    grid = sns.lmplot(
        x="num_users_boycotting", y="value", hue=hue, data=longform,
        sharey='row', sharex='col',
        size=4, 
        row=row, col='algo_name',
        fit_reg=False,
        x_estimator=np.mean, ci=99, 
        palette=palette,
        legend_out=True,
    )
    

    algo_to_size_to_decreases = defaultdict(lambda: defaultdict(list))
    for metric in metrics:
        for algo_name in algo_names:
            filt = df[df.algo_name == algo_name]
            for group in groups:
                key = 'increase_{}_{}'.format(metric, group)
                if percents:
                    key = 'percent_' + key
                x = filt.num_users_boycotting
                user_nums = sorted(list(set(filt.num_users_boycotting)))
                nrm_rounded = sorted(list(set(filt.nrm_rounded)))
                y = filt[key]

                num_to_mean = OrderedDict()
                rounded_num_to_mean = OrderedDict()
                for num_users_boycotting in user_nums:
                    filt_by_name = filt[filt.num_users_boycotting == num_users_boycotting]
                    num_to_mean[num_users_boycotting] = np.mean(filt_by_name[key])
                    rounded_num_to_mean[round(num_users_boycotting, 2)] = np.mean(filt_by_name[key])
                nrm_rounded_to_mean = OrderedDict()
                for num in nrm_rounded:
                    filt_by_nrm = filt[filt.nrm_rounded == num]
                    nrm_rounded_to_mean[num] = np.mean(filt_by_nrm[key])

                if group == 'non-boycott':
                    for num in [
                        0.1, 0.3, 0.9
                    ]:
                        
                        val_nb = rounded_num_to_mean.get(num)
                        if val_nb is None:
                            continue
                        val_all = np.mean(filt[filt.num_users_boycotting == num][key.replace('non-boycott', 'all')])
                        ratio_nb = val_nb / algo_to_metric_to_altalgo[algo_name][metric]['MovieMean']
                        ratio_all = val_all / algo_to_metric_to_altalgo[algo_name][metric]['MovieMean']
                        print(
                            'Algo:{}  |  Metric:{}  |  #users:{}'.format(
                                algo_name, metric, num, 
                            )
                        )
                        print('NB Val:{}  |  NB Ratio:{}'.format(
                            val_nb,
                            ratio_nb
                        ))
                        print('all Val:{}  |  all Ratio:{}'.format(
                            val_all,
                            ratio_all,
                        ))
                        algo_to_size_to_decreases[algo_name][num].append(ratio_nb)
                meany = np.array(list(num_to_mean.values()))
                meany_ratings = np.array(list(nrm_rounded_to_mean.values()))

                algo_to_metric_to_group_to[algo_name][metric][group]['x'] = user_nums
                algo_to_metric_to_group_to[algo_name][metric][group]['y'] = meany

                smoothf_ratings = interp1d(nrm_rounded, meany_ratings, kind='quadratic', bounds_error=False, fill_value='extrapolate')
                algo_to_metric_to_group_to[algo_name][metric][group]['interp_ratings'] = smoothf_ratings
                algo_to_metric_to_group_to[algo_name][metric][group]['max_user_units'] = max(user_nums)
                algo_to_metric_to_group_to[algo_name][metric][group]['xnew_ratings'] = np.linspace(
                    min(filt.num_ratings_missing), max(filt.num_ratings_missing), num=1000)

    for x in grid.facet_data():
        i_row, i_col, i_hue = x[0]
        metric = grid.row_names[i_row]
        algo_name = grid.col_names[i_col]
        group = grid.hue_names[i_hue]
        
        lines = {}
        lines['KNNBaseline_item_msd'] = {
            'value': algo_to_metric_to_altalgo[algo_name][metric]['KNNBaseline_item_msd'],
            'color': 'y',
            'name': 'Item KNN + Baselines: 2010',
            'linestyle': ':',
        }
        lines['MovieMean'] = {
            'value': algo_to_metric_to_altalgo[algo_name][metric]['MovieMean'],
            'color': '0.3',
            'name': 'MovieMean',
            'linestyle': '-'
        }
        lines['Zero'] = {
            'value': 0,
            'color': '0.3',
            'name': 'Zero',
            'linestyle': '-'
        }
        
        lines['KNNBasic_item_msd'] = {
            'value': algo_to_metric_to_altalgo[algo_name][metric]['KNNBasic_item_msd'],
            'color': 'r',
            'name': 'Item KNN (1999)',
            'linestyle': ':'
        }
        
        if dataset == 'ml-1m':   
            lines['KNNBasic_user_msd'] = {
                'value': algo_to_metric_to_altalgo[algo_name][metric]['KNNBasic_user_msd'],
                'color': 'c',
                'name': 'User KNN (1994)',
                'linestyle': ':'
            }
        elif dataset == 'ml-20m':
            lines['1M_SVD'] = {
                'value': algo_to_metric_to_altalgo[algo_name][metric]['1M_SVD'],
                'color': 'c',
                'name': 'ml-1m SVD',
                'linestyle': ':'
            }
        
        if normalize:
            norm_val = abs(algo_to_metric_to_altalgo[algo_name][metric]['MovieMean'])
            for key in lines.keys():
                lines[key]['value'] /= norm_val
        
        ax = grid.axes[i_row, i_col]
        
        if normalize and metric == 'ndcg10':
            if dataset == 'ml-1m':
                ax.set(ylim=(-1.6, 0.1))
            elif dataset == 'ml-20m':
                ax.set(ylim=(-1.2, 0.1))
    
        linestyle = '-' if group  != 'all' else '--'

        ax.plot(
            algo_to_metric_to_group_to[algo_name][metric][group]['x'],
            algo_to_metric_to_group_to[algo_name][metric][group]['y'],
            linestyle=linestyle, color=grid._colors[i_hue]
        )
        if show_interp:
            xnew_ratings = algo_to_metric_to_group_to[algo_name][metric][group]['xnew_ratings']
            ynew_ratings = algo_to_metric_to_group_to[algo_name][metric][group]['interp_ratings'](xnew_ratings)
            ax.plot(
                xnew_ratings * algo_to_metric_to_group_to[algo_name][metric][group]['max_user_units'] / num_ratings[dataset],
                ynew_ratings, '-')

        plt.setp(ax.get_xticklabels(), visible=True, rotation=45)
        if percents:
            
            for line in lines.values():
                ax.axhline(line['value'], color=line['color'], linestyle=line['linestyle'])
                ax.text(0.7, line['value'] + 0.05, line['name'])

    plt.subplots_adjust(hspace=0.2)
    algo_to_size_to_mean_dec = defaultdict(dict)
    for algo_name, size2dec in algo_to_size_to_decreases.items():
        for size, decs in size2dec.items():
            algo_to_size_to_mean_dec[algo_name][size] = np.mean(decs)
    print('=====\nSize to Mean Decrease')
    pprint(algo_to_size_to_mean_dec)
                   
    grid.set_xlabels('Fraction of users boycotting')
    grid.set_ylabels(YLABEL)
    if save:
        new_labels = ['All\nUsers', 'Not\nBoycotting\nUsers',]
        for t, l in zip(grid._legend.texts, new_labels): t.set_text(l)
        grid._legend.set_title('')
        grid.set_titles(TITLE)
        plt.savefig('sample.svg', bbox_inches='tight', dpi=300)
    return algo_to_metric_to_group_to

# %%
_ = p_b_curve(
    samples_df_1m[samples_df_1m.algo_name == 'SVD'], 'ml-1m',
    show_interp=False,
    percents=True, normalize=True,
    metrics=['ndcg10', ],
    groups=['non-boycott', 'all', ],
    save=False,     
)
plt.show()
# Out:
# Algo:SVD  |  Metric:ndcg10  |  #users:0.1
# NB Val:-0.06754775360839378  |  NB Ratio:0.026725689022844737
# all Val:-0.17066137274875315  |  all Ratio:0.0675232340476855
# Algo:SVD  |  Metric:ndcg10  |  #users:0.3
# NB Val:-0.2305288131116384  |  NB Ratio:0.09121015934512945
# all Val:-0.4933845828779054  |  all Ratio:0.19521068024121987
# Algo:SVD  |  Metric:ndcg10  |  #users:0.9
# NB Val:-1.5423016073244624  |  NB Ratio:0.6102212277221476
# all Val:-1.3739130434566418  |  all Ratio:0.54359724465048
# =====
# Size to Mean Decrease
# defaultdict(<class 'dict'>,
#             {'SVD': {0.1: 0.026725689022844737,
#                      0.3: 0.09121015934512945,
#                      0.9: 0.6102212277221476}})

# %%
_ = p_b_curve(
    samples_df_20m, 'ml-20m',
    show_interp=False,
    percents=True, normalize=True,
    metrics=metrics,
    groups=['non-boycott', 'all', ],
    save=False,     
)
plt.show()
# Out:
# Algo:SVD  |  Metric:rmse  |  #users:0.1
# NB Val:0.004307217848621067  |  NB Ratio:0.00021798173828606733
# all Val:nan  |  all Ratio:nan
# Algo:SVD  |  Metric:rmse  |  #users:0.3
# NB Val:0.018576501067706773  |  NB Ratio:0.0009401284393609398
# all Val:nan  |  all Ratio:nan
# Algo:SVD  |  Metric:rmse  |  #users:0.9
# NB Val:0.2180057134011388  |  NB Ratio:0.011032937277293306
# all Val:nan  |  all Ratio:nan
# Algo:SVD  |  Metric:ndcg10  |  #users:0.1
# NB Val:-0.007788517547258645  |  NB Ratio:0.0013790424111127886
# all Val:nan  |  all Ratio:nan
# Algo:SVD  |  Metric:ndcg10  |  #users:0.3
# NB Val:-0.028071160999143897  |  NB Ratio:0.004970306776880801
# all Val:nan  |  all Ratio:nan
# Algo:SVD  |  Metric:ndcg10  |  #users:0.9
# NB Val:-0.391010883628057  |  NB Ratio:0.06923276329005247
# all Val:nan  |  all Ratio:nan
# =====
# Size to Mean Decrease
# defaultdict(<class 'dict'>,
#             {'SVD': {0.1: 0.000798512074699428,
#                      0.3: 0.0029552176081208705,
#                      0.9: 0.04013285028367289}})

# %%
algo_to_metric_to_group_to = p_b_curve(
    samples_df_1m, 'ml-1m',
    metrics=metrics,
    percents=True, normalize=True, show_interp=True,
    groups=['non-boycott', 'all', ],
)
plt.show()
# Out:
# Algo:SVD  |  Metric:rmse  |  #users:0.1
# NB Val:-0.02472945762459065  |  NB Ratio:-0.0020483788354189914
# all Val:-0.13097278592843878  |  all Ratio:-0.010848676375534428
# Algo:SVD  |  Metric:rmse  |  #users:0.3
# NB Val:-0.07844807863338582  |  NB Ratio:-0.00649797445586202
# all Val:-0.3821830060587016  |  all Ratio:-0.031656803507449
# Algo:SVD  |  Metric:rmse  |  #users:0.9
# NB Val:-0.5324001719149722  |  NB Ratio:-0.0440995213352203
# all Val:-1.2259212079600144  |  all Ratio:-0.10154493051960516
# Algo:SVD  |  Metric:ndcg10  |  #users:0.1
# NB Val:-0.06754775360839378  |  NB Ratio:0.026725689022844737
# all Val:-0.17066137274875315  |  all Ratio:0.0675232340476855
# Algo:SVD  |  Metric:ndcg10  |  #users:0.3
# NB Val:-0.2305288131116384  |  NB Ratio:0.09121015934512945
# all Val:-0.4933845828779054  |  all Ratio:0.19521068024121987
# Algo:SVD  |  Metric:ndcg10  |  #users:0.9
# NB Val:-1.5423016073244624  |  NB Ratio:0.6102212277221476
# all Val:-1.3739130434566418  |  all Ratio:0.54359724465048
# =====
# Size to Mean Decrease
# defaultdict(<class 'dict'>,
#             {'SVD': {0.1: 0.012338655093712873,
#                      0.3: 0.04235609244463372,
#                      0.9: 0.28306085319346364}})

# %% [markdown]
# ## Find intersection of the non-boycott curve with horizontal lines

# %%
movie_val = -1 * dataset_to_algo_to_metric_to_altalgo['ml-1m']['SVD']['ndcg10']['MovieMean']
for group in ['all', 'non-boycott']:
    found_item, found_user = False, False
    found_itembasic = False
    for x in range(0, NUM_RATINGS, NUM_RATINGS//10000):
        y = algo_to_metric_to_group_to['SVD']['ndcg10'][group]['interp_ratings'](x)
        #print(x, y)
        if not found_item:
            if y <= dataset_to_algo_to_metric_to_altalgo['ml-1m']['SVD']['ndcg10']['KNNBaseline_item_msd']/movie_val:
                print(group + ' found item:')
                print(x/NUM_RATINGS)
                found_item = True
        if not found_user:
            if y <= dataset_to_algo_to_metric_to_altalgo['ml-1m']['SVD']['ndcg10']['KNNBasic_user_msd'] / movie_val:
                print(group + ' found user')
                print(x/NUM_RATINGS)
                found_user = True
        if not found_itembasic:
            if y <= dataset_to_algo_to_metric_to_altalgo['ml-1m']['SVD']['ndcg10']['KNNBasic_item_msd'] / movie_val:
                print(group + ' found knnbasicitem')
                print(x/NUM_RATINGS)
                found_itembasic = True
# Out:
# all found item:
# 0.0626868984382264
# all found knnbasicitem
# 0.18626107143606987
# all found user
# 0.44050793384182707
# non-boycott found item:
# 0.13637149835684342
# non-boycott found knnbasicitem
# 0.37962065928221
# non-boycott found user
# 0.6526635933089984

# %%
def half_users(df):
    return df[(
        (df.userfrac == 0.5) & (df.ratingfrac == 1.0) 
        #& (df.algo_name == 'SVD')
    )]

# %%
def half_ratings(df):
    return df[(
        (df.userfrac == 1.0) & (df.ratingfrac == 0.5)
    )]

# %%
def all_users_all_ratings(df):
    return df[(
        (df.userfrac == 1.0) & (df.ratingfrac == 1.0)
    )]

# %%
NORMALIZE = True
normed_org_df = org_df.copy()
for metric in metrics:
    for algo_name in algo_names:
        movie_val = abs(dataset_to_algo_to_metric_to_altalgo['ml-1m']['SVD'][metric]['MovieMean'])
        for group in ['non-boycott', 'like-boycott']:
            col = 'percent_increase_{}_{}'.format(metric, group)
            if NORMALIZE:
                normed_org_df.loc[
                    normed_org_df.algo_name == algo_name, col
                ] = org_df.loc[org_df.algo_name == algo_name, col] / movie_val
                
for metric in metrics:
    expec = []
    col = 'percent_increase_{}_expected'.format(metric)
    for i, row in normed_org_df.iterrows():
        x = row.num_ratings_missing
        expec.append(float(algo_to_metric_to_group_to[row.algo_name][metric]['non-boycott']['interp_ratings'](x)))
    kwargs = {col: expec}
    normed_org_df = normed_org_df.assign(**kwargs)

# %%
def plot2(
        df, metrics, groups,
        percents=False, kind='bar', size=4, flip=False, filename='tmp.svg', save=False,
        palette=None, aspect=1
    ):
    """
    TODO add a docstring
    """
    print('len of df (number of experiments included)', len(df.index))
    for name in list(set(df.name)):
        tmp = df[df.name == name].num_ratings_missing.mean()
        print('name', name)
        print('mean number of ratings missing', tmp)
        print(algo_to_metric_to_group_to['SVD']['ndcg10']['non-boycott']['interp_ratings'](tmp))
    increase_cols = select_cols(list(df.columns.values), metrics, groups, percents)
    increase_cols = [x for x in increase_cols if 'vanilla' not in x]
    longform = df[increase_cols + id_vars].melt(
        id_vars = id_vars,
        var_name='increase_type'
    )
    longform = fill_in_longform(longform)
    if flip:
        x = "name"
        y = "value"
    else:
        x = "value"
        y = "name"
    if '?' in filename:
        legend = False
    else:
        legend = True
    grid = sns.factorplot(
        x=x, y=y, hue="group", data=longform,
        size=size, kind=kind, col='algo_name', row='metric',
        sharex=False,
        row_order=metrics,
        legend=legend,
        legend_out=True,
        palette=palette,
        aspect=aspect
    )
    a = grid.axes
    
#     for metric in metrics:
#         for col in increase_cols:
#             if metric in col and 'expected' in col:
#                 expec = col
    
    name_to_ratios = defaultdict(list)
    diffs = defaultdict(list)
    name_to_counts = defaultdict(lambda: defaultdict(int))
    for x in grid.facet_data():
        i_row, i_col, i_hue = x[0]
        metric = grid.row_names[i_row]
        algo_name = grid.col_names[i_col]
        if grid.hue_names:
            group = grid.hue_names[i_hue]        
        
        if NORMALIZE:
            val = 1
        else:
            val = abs(dataset_to_algo_to_metric_to_altalgo['ml-1m']['SVD'][metric]['MovieMean'])
        
        if flip:
            grid.axes[i_row, i_col].axhline(0, color='0.7', linestyle='-')
        else:
            grid.axes[i_row, i_col].axvline(0, color='0.7', linestyle='-')
            grid.axes[i_row, i_col].axvline(val, color='0.7', linestyle='-')
        
        for col in increase_cols:
            if metric == col.split('_')[-2]:
                if 'expected' in col:
                    expec = col
                elif 'non-boycott' in col:
                    nb = col
                elif 'like-boycott' in col:
                    lb = col
        for name in list(set(longform.name)):
            mask = (
                (longform.metric == metric) &
                (longform.algo_name == algo_name) &
                (longform.name == name)
            )
            
            masked = longform[mask]
            try:
                expec_arr = np.array(masked[masked.increase_type == expec].value)
                nb_arr = np.array(masked[masked.increase_type == nb].value)
                lb_arr = np.array(masked[masked.increase_type == lb].value)
                
                expec_mean = np.mean(expec_arr)
                nb_mean = np.mean(nb_arr)
                lb_mean = np.nanmean(lb_arr)
                
                ratio = nb_mean / expec_mean
                diff = nb_mean - expec_mean
                lb_diff = lb_mean - nb_mean
                pval = stats.ttest_ind(expec_arr, nb_arr, equal_var=False).pvalue
                
                name_to_counts[name]['total'] += 1
                
                print('{} {} {}, {}, {}'.format(metric, algo_name, name, expec, nb))
                print('Ratio: {}, pval: {}'.format(ratio, pval))
                name_to_ratios[name].append(ratio)
                diffs['nb'].append(lb_diff)
                diffs['lb'].append(lb_diff)
                name_to_counts[name]['total_sig'] += 1
                if diff >= 0:
                    name_to_counts[name]['total_less'] += 1
                else:
                    name_to_counts[name]['total_more'] += 1
                print(lb)
                print('lb info', lb_diff, lb_mean, nb_mean)
                if lb_diff < 0:
                    name_to_counts[name]['total_lbless'] += 1
            except Exception as err:
                print(err)
                print(algo_name, metric)
    total = 0
    total_sig = 0
    total_less = 0
    total_more = 0
    total_lbless = 0
    
    for name, counts in name_to_counts.items():
        total += counts['total']
        total_sig += counts['total_sig']
        total_less += counts['total_less']
        total_more += counts['total_more']
        total_lbless += counts['total_lbless']
#         print(name)
#         print('{} sig, {} less, and {} more out of {} total'.format(
#             counts['total_sig'], counts['total_less'],
#             counts['total_more'], counts['total'])
#         )
#         print('Mean:')
    print('Totals:')
    print('{} lbless, {} sig, {} less, and {} more out of {} total'.format(
            total_lbless, total_sig, total_less,
            total_more, total)
        )
    if save:
        new_labels = ['Users Similar\n to Boycotting\n Users', 'Not Boycotting\n Users', 'Expected']
        for t, l in zip(grid._legend.texts, new_labels): t.set_text(l)
        if 'h2' in filename:
            grid.set_ylabels("")
        else:
            grid.set_ylabels(YLABEL)
        grid.set_xlabels("")
        grid.set_titles("")
        plt.savefig(filename, size=(3, 3), bbox_inches='tight', dpi=300)
    return grid, (total, total_sig, total_less, total_more, total_lbless), diffs

# %%
normed_org_df = normed_org_df[normed_org_df.algo_name == 'SVD']

# %%
gender_boycotts = normed_org_df[normed_org_df['type'] == 'gender']
age_boycotts = normed_org_df[normed_org_df['type'] == 'age']
occupation_boycotts = normed_org_df[normed_org_df['type'] == 'occupation']
power_boycotts = normed_org_df[normed_org_df['type'] == 'power']
genre_boycotts = normed_org_df[normed_org_df['type'] == 'genre']
state_boycotts = org_df[org_df['type'] == 'state']

# removing these from contention
# genre_strict_boycotts = org_df[org_df['type'] == 'genre_strict']

# %%
palette={'all': 'b', 'non-boycott': 'g', 'expected': 'y', 'like-boycott': 'c'}

def plot_all_three_scenarios(df, size=6):
    if False:
        all_df = all_users_all_ratings(df)
        if not all_df.empty:
            grid, (total, total_sig, total_less, total_more, total_lbless) = plot2(
                all_users_all_ratings(df),
                metrics=metrics,
                percents=True,
                groups=['all', 'non-boycott', 'expected'],
                size=size,
                palette=palette
            )
            grid.fig.suptitle('All Users, All Ratings')
            print('total1', total)
    else:
        total, total_sig, total_less, total_more, total_lbless = 0, 0, 0, 0, 0
    
    half_users_df = half_users(df)
    if not half_users_df.empty:
        grid, (total2, total_sig2, total_less2, total_more2, total_lbless2), ntd = plot2(
            half_users_df,
            metrics=metrics,
            percents=True,
            groups=['non-boycott', 'like-boycott', 'expected'],
            size=size,
            kind='bar',
            palette=palette
        )
        grid.fig.suptitle('Half Users')
        total += total2
        total_sig += total_sig2
        total_less += total_less2
        total_more += total_more2
        total_lbless += total_lbless2
        print('total2', total2, total)
        
#     half_ratings_df = half_ratings(df)
#     if not half_ratings_df.empty:
#         plot2(
#             half_ratings_df,
#             metrics=metrics,
#             percents=True,
#             groups=['non-boycott', 'boycott', 'like-boycott', 'expected'],
#             size=size,
#         ).fig.suptitle('Half Ratings')
#     plt.show()
    
    return (total, total_sig, total_less, total_more, total_lbless), ntd

# %%
running_totals = {
    'total': 0,
    'total_sig': 0,
    'total_less': 0,
    'total_more': 0,
    'total_lbless': 0
}
lbdiffs = []
diffs = []

# %% [markdown]
# # Make plots for paper here.

# %%
df1 = half_users(gender_boycotts)
df2 = half_users(genre_boycotts)
df3 = half_users(power_boycotts)

grid, (total, total_sig, total_less, total_more, total_lbless), ntd = plot2(
    pd.concat([df1[
        #(df1.name.str.contains('female')) & 
        (df1.algo_name == 'SVD')],
        df2[(df2.name.str.contains('film-noir')) & (df2.algo_name == 'SVD')],
        df3[(df3.name.str.contains('power')) & (df3.algo_name == 'SVD')]
    
    ]),
    metrics=['ndcg10'],
    percents=True,
    groups=['non-boycott', 'like-boycott', 'expected'],
    size=3.5,
    kind='bar',
    flip=True,
    filename='h1.svg', save=True,
    palette=palette,
    aspect=1.5
)

# grid, (total, total_sig, total_less, total_more) = plot2(
#     df2[(df2.name.str.contains('Film-Noir')) & (df2.algo_name == 'SVD')],
#     metrics=['ndcg10'],
#     percents=True,
#     groups=['non-boycott', 'expected', 'like-boycott',],
#     size=2.5,
#     kind='bar',
#     flip=True,
#     filename='h2.svg', save=True,
#     palette=palette
# )

# grid, (total, total_sig, total_less, total_more) = plot2(
#     df3[(df3.name.str.contains('power')) & (df3.algo_name == 'SVD')],
#     metrics=['ndcg10'],
#     percents=True,
#     groups=['non-boycott', 'expected', 'like-boycott',],
#     size=2.5,
#     kind='bar',
#     flip=True,
#     filename='h3.svg', save=True,
#     palette=palette
# )

plt.show()
# Out:
# len of df (number of experiments included) 200
# name fans of film-noir
# mean number of ratings missing 62451.2
# -0.03275427319282685
# name female users
# mean number of ratings missing 123511.54
# -0.07448639002478806
# name male users
# mean number of ratings missing 376779.58
# -0.306908762503413
# name power users
# mean number of ratings missing 190493.3
# -0.13507052541973943
# ndcg10 SVD fans of film-noir, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.5763531756770433, pval: 3.127638858905848e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.18254269867575848 -0.23420138122254908 -0.051658682546790596
# ndcg10 SVD female users, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.8190386156915364, pval: 0.0011278106612399785
# percent_increase_ndcg10_like-boycott
# lb info -0.07584222634311277 -0.13686491839117532 -0.06102269204806254
# ndcg10 SVD male users, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.1037527613338642, pval: 4.340262127766609e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.06495540583386639 -0.40376148216904434 -0.33880607633517795
# ndcg10 SVD power users, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.9219749317098647, pval: 1.888571597392599e-25
# percent_increase_ndcg10_like-boycott
# lb info -0.17160899698727078 -0.43120204728637956 -0.2595930502991088
# Totals:
# 4 lbless, 4 sig, 1 less, and 3 more out of 4 total

# %% [markdown]
# ## Male User and Female User Boycotts

# %%
(total, total_sig, total_less, total_more, total_lbless), ntd = plot_all_three_scenarios(gender_boycotts)
running_totals['total'] += total
running_totals['total_sig'] += total_sig
running_totals['total_less'] += total_less
running_totals['total_more'] += total_more
running_totals['total_lbless'] += total_lbless
lbdiffs += ntd['lb']
diffs += ntd['nb']
print(diffs)
plt.show()
# Out:
# len of df (number of experiments included) 100
# name female users
# mean number of ratings missing 123511.54
# -0.07448639002478806
# name male users
# mean number of ratings missing 376779.58
# -0.306908762503413
# rmse SVD female users, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.7924713610352061, pval: 5.050955975629304e-55
# percent_increase_rmse_like-boycott
# lb info 0.02114736552269237 0.042800725555350375 0.021653360032658005
# rmse SVD male users, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.090665780852551, pval: 3.4497250155333003e-77
# percent_increase_rmse_like-boycott
# lb info 0.017843204166975574 0.1307526942239034 0.11290949005692782
# ndcg10 SVD female users, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.8190386156915364, pval: 0.0011278106612399785
# percent_increase_ndcg10_like-boycott
# lb info -0.07584222634311277 -0.13686491839117532 -0.06102269204806254
# ndcg10 SVD male users, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.1037527613338642, pval: 4.340262127766609e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.06495540583386639 -0.40376148216904434 -0.33880607633517795
# Totals:
# 2 lbless, 4 sig, 3 less, and 1 more out of 4 total
# total2 4 4
# [0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639]

# %% [markdown]
# # Power Boycotts
#
# Below, the power boycotts show a very weird results. Warrants double checks.

# %%
(total, total_sig, total_less, total_more, total_lbless), ntd = plot_all_three_scenarios(power_boycotts)
running_totals['total'] += total
running_totals['total_sig'] += total_sig
running_totals['total_less'] += total_less
running_totals['total_more'] += total_more
running_totals['total_lbless'] += total_lbless
lbdiffs += ntd['lb']
diffs += ntd['nb']


plt.show()
# Out:
# len of df (number of experiments included) 100
# name bottom 10% contributors
# mean number of ratings missing 7203.8
# -0.009522238405874552
# name power users
# mean number of ratings missing 190493.3
# -0.13507052541973943
# rmse SVD bottom 10% contributors, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.350644515121868, pval: 2.8986606142052705e-14
# percent_increase_rmse_like-boycott
# lb info 0.03709913979993391 0.039033819692498556 0.0019346798925646462
# rmse SVD power users, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.8928021209406578, pval: 2.4384528315978702e-67
# percent_increase_rmse_like-boycott
# lb info 0.02582098747908855 0.11521803558504057 0.08939704810595202
# ndcg10 SVD bottom 10% contributors, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: -0.34807582946499954, pval: 0.005228589684450362
# percent_increase_ndcg10_like-boycott
# lb info -1.165898456682662 -1.1625839952011454 0.0033144614815165912
# ndcg10 SVD power users, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.9219749317098647, pval: 1.888571597392599e-25
# percent_increase_ndcg10_like-boycott
# lb info -0.17160899698727078 -0.43120204728637956 -0.2595930502991088
# Totals:
# 2 lbless, 4 sig, 3 less, and 1 more out of 4 total
# total2 4 4

# %%
(total, total_sig, total_less, total_more, total_lbless), ntd = plot_all_three_scenarios(age_boycotts)
running_totals['total'] += total
running_totals['total_sig'] += total_sig
running_totals['total_less'] += total_less
running_totals['total_more'] += total_more
running_totals['total_lbless'] += total_lbless
lbdiffs += ntd['lb']
diffs += ntd['nb']
print(diffs)


plt.show()
# Out:
# len of df (number of experiments included) 350
# name 25-34
# mean number of ratings missing 198083.06
# -0.14185472109548397
# name 56+
# mean number of ratings missing 19358.08
# -0.013449096898182182
# name under 18
# mean number of ratings missing 13690.38
# -0.011534835512748715
# name 50-55
# mean number of ratings missing 36044.12
# -0.019928060213786628
# name 45-49
# mean number of ratings missing 42237.56
# -0.022653249723358672
# name 35-44
# mean number of ratings missing 99157.22
# -0.055820221961350155
# name 18-24
# mean number of ratings missing 91599.78
# -0.05057312283053206
# rmse SVD 25-34, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0720045451973486, pval: 6.372962456916914e-70
# percent_increase_rmse_like-boycott
# lb info 0.018326610538816214 0.07133864530755836 0.053012034768742146
# rmse SVD 56+, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.5356130389619701, pval: 5.830133562964462e-23
# percent_increase_rmse_like-boycott
# lb info 0.019602181968689205 0.02328945966695749 0.0036872776982682853
# rmse SVD under 18, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9697175534327389, pval: 1.1752243682862751e-29
# percent_increase_rmse_like-boycott
# lb info 0.023450228567282332 0.029482757435129733 0.0060325288678473995
# rmse SVD 50-55, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0504384736075023, pval: 8.732295483151622e-31
# percent_increase_rmse_like-boycott
# lb info -0.009596665288711026 -2.794642504923138e-05 0.009568718863661795
# rmse SVD 45-49, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0298537150470004, pval: 2.0385172545723916e-37
# percent_increase_rmse_like-boycott
# lb info 0.02039143144385172 0.030726754578427593 0.010335323134575873
# rmse SVD 35-44, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0642550226664178, pval: 8.468862220992108e-51
# percent_increase_rmse_like-boycott
# lb info 0.013257148121160613 0.03576622106792914 0.02250907294676853
# rmse SVD 18-24, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.3730600182620774, pval: 3.2904851830222673e-53
# percent_increase_rmse_like-boycott
# lb info 0.027814882964055578 0.05445800291328079 0.026643119949225212
# ndcg10 SVD 25-34, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.0907850946430042, pval: 0.0116840747795583
# percent_increase_ndcg10_like-boycott
# lb info -0.024862169783425536 -0.17958437518248715 -0.15472220539906162
# ndcg10 SVD 56+, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: -0.24875082054393027, pval: 0.00026893776466765457
# percent_increase_ndcg10_like-boycott
# lb info -0.056760111460816325 -0.05341410345423272 0.003346008006583604
# ndcg10 SVD under 18, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.024737813912758252, pval: 0.007684798926695389
# percent_increase_ndcg10_like-boycott
# lb info -0.3238456659474422 -0.32413108004612873 -0.00028541409868656386
# ndcg10 SVD 50-55, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.0056644695039294, pval: 0.9783410632196461
# percent_increase_ndcg10_like-boycott
# lb info -0.08478266186702534 -0.10483501979045604 -0.0200523579234307
# ndcg10 SVD 45-49, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.107922444384995, pval: 0.5452127227407206
# percent_increase_ndcg10_like-boycott
# lb info -0.07340881502334753 -0.09851792964166284 -0.0251091146183153
# ndcg10 SVD 35-44, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.093822446282293, pval: 0.19782415976206233
# percent_increase_ndcg10_like-boycott
# lb info -0.05291675983953624 -0.11401099048113598 -0.061094230641599745
# ndcg10 SVD 18-24, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.3832300566814733, pval: 2.0750800610582688e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.07422645573381648 -0.1442168794573742 -0.06999042372355771
# Totals:
# 8 lbless, 14 sig, 9 less, and 5 more out of 14 total
# total2 14 14
# [0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.03709913979993391, 0.02582098747908855, -1.165898456682662, -0.17160899698727078, 0.018326610538816214, 0.019602181968689205, 0.023450228567282332, -0.009596665288711026, 0.02039143144385172, 0.013257148121160613, 0.027814882964055578, -0.024862169783425536, -0.056760111460816325, -0.3238456659474422, -0.08478266186702534, -0.07340881502334753, -0.05291675983953624, -0.07422645573381648]

# %%
(total, total_sig, total_less, total_more, total_lbless), ntd = plot_all_three_scenarios(occupation_boycotts)
running_totals['total'] += total
running_totals['total_sig'] += total_sig
running_totals['total_less'] += total_less
running_totals['total_more'] += total_more
running_totals['total_lbless'] += total_lbless
lbdiffs += ntd['lb']
diffs += ntd['nb']

plt.show()
# Out:
# len of df (number of experiments included) 1050
# name k-12 student
# mean number of ratings missing 11535.26
# -0.01084506035956718
# name programmer
# mean number of ratings missing 29008.7
# -0.017042802650470642
# name lawyer
# mean number of ratings missing 10196.7
# -0.010427208827199722
# name clerical/admin
# mean number of ratings missing 15823.08
# -0.012238108980529856
# name retired
# mean number of ratings missing 6870.72
# -0.009424028747092908
# name self-employed
# mean number of ratings missing 23290.52
# -0.014862624986925026
# name technician/engineer
# mean number of ratings missing 36241.4
# -0.02001219148722595
# name tradesman/craftsman
# mean number of ratings missing 6110.76
# -0.009201830178689807
# name artist
# mean number of ratings missing 25329.26
# -0.015622978772655302
# name other
# mean number of ratings missing 65251.36
# -0.034299241054837504
# name unemployed
# mean number of ratings missing 7359.78
# -0.009568402048394934
# name writer
# mean number of ratings missing 30108.58
# -0.01747910908397002
# name college/grad student
# mean number of ratings missing 66071.66
# -0.03475854984902621
# name farmer
# mean number of ratings missing 1253.44
# -0.007843323213116154
# name executive/managerial
# mean number of ratings missing 52456.28
# -0.027528772473712645
# name homemaker
# mean number of ratings missing 5503.74
# -0.009026224473556508
# name customer service
# mean number of ratings missing 10833.14
# -0.010624872843608335
# name doctor/health care
# mean number of ratings missing 18606.76
# -0.013186988271604647
# name academic/educator
# mean number of ratings missing 42309.38
# -0.02268586869550117
# name sales/marketing
# mean number of ratings missing 24560.24
# -0.015333963082252045
# name scientist
# mean number of ratings missing 11355.72
# -0.010788543812439162
# rmse SVD k-12 student, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.7530611944819203, pval: 1.579701466255605e-23
# percent_increase_rmse_like-boycott
# lb info 0.023444208920187577 0.027948012129348797 0.004503803209161219
# rmse SVD programmer, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9550964435702576, pval: 1.902742301858933e-32
# percent_increase_rmse_like-boycott
# lb info 0.0025347095324398 0.010290979953131697 0.007756270420691897
# rmse SVD lawyer, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.7575471564994343, pval: 5.157458342114271e-25
# percent_increase_rmse_like-boycott
# lb info 0.03277218706462173 0.037192275601164226 0.004420088536542493
# rmse SVD clerical/admin, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.8363238781588905, pval: 8.856734684354954e-26
# percent_increase_rmse_like-boycott
# lb info -0.01811743858140226 -0.012710237909183604 0.005407200672218655
# rmse SVD retired, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.6234008620000187, pval: 2.4906988130144437e-21
# percent_increase_rmse_like-boycott
# lb info 0.015395005199962397 0.018813272535529876 0.0034182673355674788
# rmse SVD self-employed, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9922469418199586, pval: 2.3109083819210413e-35
# percent_increase_rmse_like-boycott
# lb info -0.00794429135504057 -0.0006289862138416864 0.007315305141198884
# rmse SVD technician/engineer, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.071456318976914, pval: 1.8637874333430365e-35
# percent_increase_rmse_like-boycott
# lb info 0.00653836697899114 0.016329202114845218 0.009790835135854077
# rmse SVD tradesman/craftsman, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9534732278533828, pval: 3.440674901158624e-29
# percent_increase_rmse_like-boycott
# lb info -0.03288265210070527 -0.02772843514087911 0.00515421695982616
# rmse SVD artist, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.039343710953799, pval: 2.3781371865942417e-32
# percent_increase_rmse_like-boycott
# lb info 0.010348999682668964 0.018283970005784734 0.00793497032311577
# rmse SVD other, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.23116260493861, pval: 1.3485826540581863e-44
# percent_increase_rmse_like-boycott
# lb info 0.0007338801606535592 0.01793149079360673 0.01719761063295317
# rmse SVD unemployed, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.8755775818039953, pval: 7.76127721303849e-26
# percent_increase_rmse_like-boycott
# lb info 0.008224407048212456 0.013070213420188406 0.004845806371975949
# rmse SVD writer, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.3208570920533327, pval: 3.825196495987525e-36
# percent_increase_rmse_like-boycott
# lb info 0.01913482821130199 0.030060368713608523 0.010925540502306534
# rmse SVD college/grad student, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.2564802795492733, pval: 4.157420612518307e-40
# percent_increase_rmse_like-boycott
# lb info 0.010949871608279215 0.028689897236437424 0.01774002562815821
# rmse SVD farmer, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.7816584555321381, pval: 2.7460415336052022e-24
# percent_increase_rmse_like-boycott
# lb info 0.00862235096048846 0.012473191390620801 0.0038508404301323407
# rmse SVD executive/managerial, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.1790660890167026, pval: 1.8274273016402778e-40
# percent_increase_rmse_like-boycott
# lb info -0.007441703944825233 0.006338124699092673 0.013779828643917906
# rmse SVD homemaker, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.8109937642765354, pval: 7.223396087191791e-23
# percent_increase_rmse_like-boycott
# lb info -0.009659466793135264 -0.005325693982990516 0.004333772810144748
# rmse SVD customer service, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.822350341661914, pval: 5.0108581994243156e-24
# percent_increase_rmse_like-boycott
# lb info 0.009055090437814033 0.013910230468799002 0.004855140030984968
# rmse SVD doctor/health care, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.1240374243480578, pval: 4.407674913096058e-31
# percent_increase_rmse_like-boycott
# lb info 0.0028719734419765976 0.010509217566510576 0.007637244124533978
# rmse SVD academic/educator, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0918959325168653, pval: 5.638215658321807e-37
# percent_increase_rmse_like-boycott
# lb info -0.0033062634153404064 0.007664134327662688 0.010970397743003095
# rmse SVD sales/marketing, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9104889941926816, pval: 9.63069768609041e-33
# percent_increase_rmse_like-boycott
# lb info 0.01199242647786203 0.018852908778951957 0.006860482301089927
# rmse SVD scientist, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.653091488362986, pval: 1.2392289622433195e-20
# percent_increase_rmse_like-boycott
# lb info -0.018267834818198197 -0.014374922217417074 0.003892912600781123
# ndcg10 SVD k-12 student, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: -0.770889019658599, pval: 2.8505773116188702e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.38292186493328445 -0.3745596914345875 0.008362173498696923
# ndcg10 SVD programmer, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.1648195525518847, pval: 0.54224371498147
# percent_increase_ndcg10_like-boycott
# lb info 0.0183257939777578 -0.0015301073213317134 -0.019855901299089512
# ndcg10 SVD lawyer, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.5030996627810906, pval: 0.24306386731596322
# percent_increase_ndcg10_like-boycott
# lb info -0.04911752514640094 -0.0543644295933123 -0.005246904446911358
# ndcg10 SVD clerical/admin, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.4881381985732275, pval: 0.14394920643048353
# percent_increase_ndcg10_like-boycott
# lb info 0.197728386057877 0.19175271857121573 -0.005975667486661252
# ndcg10 SVD retired, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: -0.45489036068186833, pval: 0.001633036583489403
# percent_increase_ndcg10_like-boycott
# lb info 0.07101097133003835 0.07529815624863322 0.004287184918594862
# ndcg10 SVD self-employed, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.8718744184731234, pval: 0.5431225069758141
# percent_increase_ndcg10_like-boycott
# lb info -0.00911094732622441 -0.02207305300275681 -0.012962105676532401
# ndcg10 SVD technician/engineer, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.0723666975543225, pval: 0.724439145683498
# percent_increase_ndcg10_like-boycott
# lb info -0.07587642361101839 -0.09734881094809676 -0.021472387337078378
# ndcg10 SVD tradesman/craftsman, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: -0.19526414820974602, pval: 0.0019175307985113607
# percent_increase_ndcg10_like-boycott
# lb info 0.1315197912627244 0.1333169754305048 0.001797184167780399
# ndcg10 SVD artist, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.6699649302324154, pval: 0.2156844054992115
# percent_increase_ndcg10_like-boycott
# lb info 0.003849788854826925 -0.006621197798673837 -0.010470986653500762
# ndcg10 SVD other, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.045562491478778, pval: 0.6466546540061002
# percent_increase_ndcg10_like-boycott
# lb info -0.07791040166488448 -0.11379723885774755 -0.035886837192863064
# ndcg10 SVD unemployed, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.17331998729908657, pval: 0.041213699812644604
# percent_increase_ndcg10_like-boycott
# lb info 0.0194582653264769 0.017799471542134886 -0.0016587937843420138
# ndcg10 SVD writer, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.294205082974319, pval: 0.19638605025936512
# percent_increase_ndcg10_like-boycott
# lb info 0.08476284966873182 0.06213182527913773 -0.022631024389594096
# ndcg10 SVD college/grad student, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.211252920012669, pval: 0.07667320096086157
# percent_increase_ndcg10_like-boycott
# lb info 0.03473085400089548 -0.007384560078813396 -0.042115414079708875
# ndcg10 SVD farmer, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.4612558483370206, pval: 0.23420567565902503
# percent_increase_ndcg10_like-boycott
# lb info -0.6671422822242367 -0.6707602825274377 -0.003618000303201079
# ndcg10 SVD executive/managerial, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.081651515767446, pval: 0.6611744956640171
# percent_increase_ndcg10_like-boycott
# lb info -0.01602541212569883 -0.04581686198454594 -0.02979144985884711
# ndcg10 SVD homemaker, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: -0.412403084136799, pval: 0.004765290409912307
# percent_increase_ndcg10_like-boycott
# lb info -0.25942917693764345 -0.2557062341165963 0.003722942821047121
# ndcg10 SVD customer service, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.03223918127260101, pval: 0.005532612757671174
# percent_increase_ndcg10_like-boycott
# lb info -0.41496029200860923 -0.4153029171709041 -0.0003426251622949013
# ndcg10 SVD doctor/health care, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.7914675091658282, pval: 0.5453968479252668
# percent_increase_ndcg10_like-boycott
# lb info -0.22790064299734622 -0.23834157695354466 -0.010440933956198446
# ndcg10 SVD academic/educator, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.052907943226683, pval: 0.7605376447228201
# percent_increase_ndcg10_like-boycott
# lb info 0.0024312017968756774 -0.021466498154891184 -0.02389769995176686
# ndcg10 SVD sales/marketing, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.2321894515398484, pval: 0.2830791549270915
# percent_increase_ndcg10_like-boycott
# lb info 0.18125179433388316 0.16235098388594266 -0.0189008104479405
# ndcg10 SVD scientist, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.44399082137063095, pval: 0.18905282100891202
# percent_increase_ndcg10_like-boycott
# lb info 0.31898281350047825 0.31419203476218394 -0.0047907787382943014
# Totals:
# 17 lbless, 42 sig, 34 less, and 8 more out of 42 total
# total2 42 42

# %%
(total, total_sig, total_less, total_more, total_lbless), ntd = plot_all_three_scenarios(genre_boycotts)
running_totals['total'] += total
running_totals['total_sig'] += total_sig
running_totals['total_less'] += total_less
running_totals['total_more'] += total_more
running_totals['total_lbless'] += total_lbless
lbdiffs.append(ntd['lb'])
diffs.append(ntd['nb'])

plt.show()
# Out:
# len of df (number of experiments included) 900
# name fans of thriller
# mean number of ratings missing 81594.02
# -0.04402346188002808
# name fans of documentary
# mean number of ratings missing 21935.28
# -0.014367583318173376
# name fans of action
# mean number of ratings missing 62366.34
# -0.03270800580062659
# name fans of adventure
# mean number of ratings missing 50984.28
# -0.02679734846093064
# name fans of crime
# mean number of ratings missing 88889.1
# -0.04875403501147191
# name fans of mystery
# mean number of ratings missing 53123.44
# -0.027863505002028548
# name fans of fantasy
# mean number of ratings missing 22704.66
# -0.014647603167603168
# name fans of horror
# mean number of ratings missing 24026.48
# -0.015134935691445101
# name fans of musical
# mean number of ratings missing 60274.1
# -0.03157757209503026
# name fans of romance
# mean number of ratings missing 74698.48
# -0.03977319799343347
# name fans of western
# mean number of ratings missing 26247.58
# -0.015971608034535945
# name fans of war
# mean number of ratings missing 133979.3
# -0.083333398826304
# name fans of sci-fi
# mean number of ratings missing 51069.32
# -0.02683933744408911
# name fans of film-noir
# mean number of ratings missing 62451.2
# -0.03275427319282685
# name fans of children's
# mean number of ratings missing 43274.4
# -0.023126420401479306
# name fans of drama
# mean number of ratings missing 142915.76
# -0.09127823603564615
# name fans of comedy
# mean number of ratings missing 75152.92
# -0.04004668756690045
# name fans of animation
# mean number of ratings missing 62075.76
# -0.03254982233644335
# rmse SVD fans of thriller, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.8759977269290831, pval: 9.07777963245992e-43
# percent_increase_rmse_like-boycott
# lb info 0.005195085869632717 0.020277293981534453 0.015082208111901736
# rmse SVD fans of documentary, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.4566155365696276, pval: 3.29863392309841e-33
# percent_increase_rmse_like-boycott
# lb info -0.0029625053321351126 0.007528156300590114 0.010490661632725226
# rmse SVD fans of action, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.8338986470476626, pval: 1.347742308598148e-40
# percent_increase_rmse_like-boycott
# lb info 0.00352622553456281 0.01472493866683253 0.01119871313226972
# rmse SVD fans of adventure, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.8956674878234904, pval: 1.0413841648138641e-38
# percent_increase_rmse_like-boycott
# lb info 0.007980687804398213 0.018224932559854898 0.010244244755456685
# rmse SVD fans of crime, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0729389668940659, pval: 1.579201535128607e-49
# percent_increase_rmse_like-boycott
# lb info 0.011790717771499683 0.031955484471303 0.02016476669980332
# rmse SVD fans of mystery, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.2750014857827996, pval: 2.5091789583358113e-43
# percent_increase_rmse_like-boycott
# lb info 0.007596408480514558 0.022639946085904982 0.015043537605390424
# rmse SVD fans of fantasy, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.1997502478323405, pval: 8.713248600510556e-29
# percent_increase_rmse_like-boycott
# lb info 0.018080663906479524 0.026836659295851342 0.008755995389371819
# rmse SVD fans of horror, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0318900109922937, pval: 3.104029806798836e-32
# percent_increase_rmse_like-boycott
# lb info 0.02035892738371975 0.02806329409540198 0.007704366711682232
# rmse SVD fans of musical, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.4698543653209406, pval: 4.110490263064527e-44
# percent_increase_rmse_like-boycott
# lb info 0.012606554307250849 0.03178980379902461 0.01918324949177376
# rmse SVD fans of romance, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9983277781825659, pval: 1.3279354636896691e-45
# percent_increase_rmse_like-boycott
# lb info 0.00742358823292948 0.0231949359995913 0.01577134776666182
# rmse SVD fans of western, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.4320917831986826, pval: 5.149353719186228e-37
# percent_increase_rmse_like-boycott
# lb info -0.0025480790502778756 0.00855665585499918 0.011104734905277056
# rmse SVD fans of war, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.06886947865368, pval: 5.5426688612549565e-64
# percent_increase_rmse_like-boycott
# lb info -0.0010086544434470962 0.031314769302910064 0.03232342374635716
# rmse SVD fans of sci-fi, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.9057662976976204, pval: 3.8704760731318395e-38
# percent_increase_rmse_like-boycott
# lb info 0.01594278752132619 0.026315356815612 0.01037256929428581
# rmse SVD fans of film-noir, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.82480461423599, pval: 8.536928904376708e-48
# percent_increase_rmse_like-boycott
# lb info 0.005611947978484189 0.030151159104763778 0.02453921112627959
# rmse SVD fans of children's, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.0647376285475643, pval: 5.8480094288148206e-40
# percent_increase_rmse_like-boycott
# lb info 0.01643050246576487 0.02728666199972284 0.01085615953395797
# rmse SVD fans of drama, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.7221703830944288, pval: 2.3926414466278044e-57
# percent_increase_rmse_like-boycott
# lb info 0.004737160789802259 0.028468498293612726 0.023731337503810467
# rmse SVD fans of comedy, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -0.6247847136632428, pval: 1.096224852906033e-43
# percent_increase_rmse_like-boycott
# lb info 0.008288686458528427 0.01821559905684694 0.009926912598318512
# rmse SVD fans of animation, percent_increase_rmse_expected, percent_increase_rmse_non-boycott
# Ratio: -1.3965850270711124, pval: 3.5788121874804774e-47
# percent_increase_rmse_like-boycott
# lb info 0.010820545638570607 0.02950600347465761 0.018685457836087004
# ndcg10 SVD fans of thriller, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.666520014392315, pval: 0.0006663374021855993
# percent_increase_ndcg10_like-boycott
# lb info -0.06844221095227779 -0.09779101587219677 -0.029348804919918984
# ndcg10 SVD fans of documentary, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.4693934201079186, pval: 0.08613691880757338
# percent_increase_ndcg10_like-boycott
# lb info -0.1524936080835349 -0.17361231246279632 -0.021118704379261423
# ndcg10 SVD fans of action, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.4610704404307242, pval: 9.266590448095004e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.05034776084376496 -0.06543227698554707 -0.015084516141782113
# ndcg10 SVD fans of adventure, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.5078541847198598, pval: 0.0033790510599353597
# percent_increase_ndcg10_like-boycott
# lb info -0.07834766365025918 -0.09195976538037783 -0.013612101730118651
# ndcg10 SVD fans of crime, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.03630617293234, pval: 0.6948370108392214
# percent_increase_ndcg10_like-boycott
# lb info -0.0664415480117897 -0.11697667342360722 -0.050535125411817525
# ndcg10 SVD fans of mystery, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.4369494408997614, pval: 0.0026925178380711916
# percent_increase_ndcg10_like-boycott
# lb info -0.12026763165519014 -0.16032048423280465 -0.040052852577614505
# ndcg10 SVD fans of fantasy, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.6468418487742544, pval: 0.22353016108927676
# percent_increase_ndcg10_like-boycott
# lb info -0.09266760207328283 -0.10214460280872247 -0.00947700073543964
# ndcg10 SVD fans of horror, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.9874125501302651, pval: 0.9629619140025099
# percent_increase_ndcg10_like-boycott
# lb info -0.05901679041946104 -0.07396572991939268 -0.01494893949993164
# ndcg10 SVD fans of musical, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.2225495973163756, pval: 0.10979868291789056
# percent_increase_ndcg10_like-boycott
# lb info -0.03017192104612388 -0.06879397765052006 -0.03862205660439618
# ndcg10 SVD fans of romance, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.9294390084840716, pval: 0.5425049027212141
# percent_increase_ndcg10_like-boycott
# lb info -0.05842880243947232 -0.0954047442693713 -0.03697594182989898
# ndcg10 SVD fans of western, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.4051270140850243, pval: 0.13052819374012772
# percent_increase_ndcg10_like-boycott
# lb info 0.033421336665234544 0.010971197120135723 -0.022450139545098825
# ndcg10 SVD fans of war, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.075498362290178, pval: 0.14261502475471843
# percent_increase_ndcg10_like-boycott
# lb info -0.04217143120816286 -0.13181229448869153 -0.08964086328052867
# ndcg10 SVD fans of sci-fi, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.36175336848209116, pval: 4.7343029937982564e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.15965960118571598 -0.16937089256977958 -0.009711291384063583
# ndcg10 SVD fans of film-noir, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.5763531756770433, pval: 3.127638858905848e-05
# percent_increase_ndcg10_like-boycott
# lb info -0.18254269867575848 -0.23420138122254908 -0.051658682546790596
# ndcg10 SVD fans of children's, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.6717909888304706, pval: 0.04063113265097606
# percent_increase_ndcg10_like-boycott
# lb info -0.07075534277333252 -0.08629774958166692 -0.01554240680833439
# ndcg10 SVD fans of drama, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.5172314763524839, pval: 6.026582232044233e-12
# percent_increase_ndcg10_like-boycott
# lb info -0.039945490102568544 -0.0871718091829008 -0.04722631908033225
# ndcg10 SVD fans of comedy, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 0.1911812093465949, pval: 3.4291557482114623e-09
# percent_increase_ndcg10_like-boycott
# lb info -0.030208322279931695 -0.037865978912964574 -0.0076576566330328775
# ndcg10 SVD fans of animation, percent_increase_ndcg10_expected, percent_increase_ndcg10_non-boycott
# Ratio: 1.1812779613249467, pval: 0.0464406449301811
# percent_increase_ndcg10_like-boycott
# lb info 0.012914031850264594 -0.025557999374123702 -0.038472031224388296
# Totals:
# 19 lbless, 36 sig, 28 less, and 8 more out of 36 total
# total2 36 36

# %%
running_totals
# Out:
# {'total': 104,
#  'total_lbless': 50,
#  'total_less': 80,
#  'total_more': 24,
#  'total_sig': 104}

# %%
print(lbdiffs)
print(diffs)
# Out:
# [0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.03709913979993391, 0.02582098747908855, -1.165898456682662, -0.17160899698727078, 0.018326610538816214, 0.019602181968689205, 0.023450228567282332, -0.009596665288711026, 0.02039143144385172, 0.013257148121160613, 0.027814882964055578, -0.024862169783425536, -0.056760111460816325, -0.3238456659474422, -0.08478266186702534, -0.07340881502334753, -0.05291675983953624, -0.07422645573381648, 0.023444208920187577, 0.0025347095324398, 0.03277218706462173, -0.01811743858140226, 0.015395005199962397, -0.00794429135504057, 0.00653836697899114, -0.03288265210070527, 0.010348999682668964, 0.0007338801606535592, 0.008224407048212456, 0.01913482821130199, 0.010949871608279215, 0.00862235096048846, -0.007441703944825233, -0.009659466793135264, 0.009055090437814033, 0.0028719734419765976, -0.0033062634153404064, 0.01199242647786203, -0.018267834818198197, -0.38292186493328445, 0.0183257939777578, -0.04911752514640094, 0.197728386057877, 0.07101097133003835, -0.00911094732622441, -0.07587642361101839, 0.1315197912627244, 0.003849788854826925, -0.07791040166488448, 0.0194582653264769, 0.08476284966873182, 0.03473085400089548, -0.6671422822242367, -0.01602541212569883, -0.25942917693764345, -0.41496029200860923, -0.22790064299734622, 0.0024312017968756774, 0.18125179433388316, 0.31898281350047825, [0.005195085869632717, -0.0029625053321351126, 0.00352622553456281, 0.007980687804398213, 0.011790717771499683, 0.007596408480514558, 0.018080663906479524, 0.02035892738371975, 0.012606554307250849, 0.00742358823292948, -0.0025480790502778756, -0.0010086544434470962, 0.01594278752132619, 0.005611947978484189, 0.01643050246576487, 0.004737160789802259, 0.008288686458528427, 0.010820545638570607, -0.06844221095227779, -0.1524936080835349, -0.05034776084376496, -0.07834766365025918, -0.0664415480117897, -0.12026763165519014, -0.09266760207328283, -0.05901679041946104, -0.03017192104612388, -0.05842880243947232, 0.033421336665234544, -0.04217143120816286, -0.15965960118571598, -0.18254269867575848, -0.07075534277333252, -0.039945490102568544, -0.030208322279931695, 0.012914031850264594], 0.023444208920187577, 0.0025347095324398, 0.03277218706462173, -0.01811743858140226, 0.015395005199962397, -0.00794429135504057, 0.00653836697899114, -0.03288265210070527, 0.010348999682668964, 0.0007338801606535592, 0.008224407048212456, 0.01913482821130199, 0.010949871608279215, 0.00862235096048846, -0.007441703944825233, -0.009659466793135264, 0.009055090437814033, 0.0028719734419765976, -0.0033062634153404064, 0.01199242647786203, -0.018267834818198197, -0.38292186493328445, 0.0183257939777578, -0.04911752514640094, 0.197728386057877, 0.07101097133003835, -0.00911094732622441, -0.07587642361101839, 0.1315197912627244, 0.003849788854826925, -0.07791040166488448, 0.0194582653264769, 0.08476284966873182, 0.03473085400089548, -0.6671422822242367, -0.01602541212569883, -0.25942917693764345, -0.41496029200860923, -0.22790064299734622, 0.0024312017968756774, 0.18125179433388316, 0.31898281350047825]
# [0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.02114736552269237, 0.017843204166975574, -0.07584222634311277, -0.06495540583386639, 0.03709913979993391, 0.02582098747908855, -1.165898456682662, -0.17160899698727078, 0.018326610538816214, 0.019602181968689205, 0.023450228567282332, -0.009596665288711026, 0.02039143144385172, 0.013257148121160613, 0.027814882964055578, -0.024862169783425536, -0.056760111460816325, -0.3238456659474422, -0.08478266186702534, -0.07340881502334753, -0.05291675983953624, -0.07422645573381648, 0.023444208920187577, 0.0025347095324398, 0.03277218706462173, -0.01811743858140226, 0.015395005199962397, -0.00794429135504057, 0.00653836697899114, -0.03288265210070527, 0.010348999682668964, 0.0007338801606535592, 0.008224407048212456, 0.01913482821130199, 0.010949871608279215, 0.00862235096048846, -0.007441703944825233, -0.009659466793135264, 0.009055090437814033, 0.0028719734419765976, -0.0033062634153404064, 0.01199242647786203, -0.018267834818198197, -0.38292186493328445, 0.0183257939777578, -0.04911752514640094, 0.197728386057877, 0.07101097133003835, -0.00911094732622441, -0.07587642361101839, 0.1315197912627244, 0.003849788854826925, -0.07791040166488448, 0.0194582653264769, 0.08476284966873182, 0.03473085400089548, -0.6671422822242367, -0.01602541212569883, -0.25942917693764345, -0.41496029200860923, -0.22790064299734622, 0.0024312017968756774, 0.18125179433388316, 0.31898281350047825, [0.005195085869632717, -0.0029625053321351126, 0.00352622553456281, 0.007980687804398213, 0.011790717771499683, 0.007596408480514558, 0.018080663906479524, 0.02035892738371975, 0.012606554307250849, 0.00742358823292948, -0.0025480790502778756, -0.0010086544434470962, 0.01594278752132619, 0.005611947978484189, 0.01643050246576487, 0.004737160789802259, 0.008288686458528427, 0.010820545638570607, -0.06844221095227779, -0.1524936080835349, -0.05034776084376496, -0.07834766365025918, -0.0664415480117897, -0.12026763165519014, -0.09266760207328283, -0.05901679041946104, -0.03017192104612388, -0.05842880243947232, 0.033421336665234544, -0.04217143120816286, -0.15965960118571598, -0.18254269867575848, -0.07075534277333252, -0.039945490102568544, -0.030208322279931695, 0.012914031850264594], 0.023444208920187577, 0.0025347095324398, 0.03277218706462173, -0.01811743858140226, 0.015395005199962397, -0.00794429135504057, 0.00653836697899114, -0.03288265210070527, 0.010348999682668964, 0.0007338801606535592, 0.008224407048212456, 0.01913482821130199, 0.010949871608279215, 0.00862235096048846, -0.007441703944825233, -0.009659466793135264, 0.009055090437814033, 0.0028719734419765976, -0.0033062634153404064, 0.01199242647786203, -0.018267834818198197, -0.38292186493328445, 0.0183257939777578, -0.04911752514640094, 0.197728386057877, 0.07101097133003835, -0.00911094732622441, -0.07587642361101839, 0.1315197912627244, 0.003849788854826925, -0.07791040166488448, 0.0194582653264769, 0.08476284966873182, 0.03473085400089548, -0.6671422822242367, -0.01602541212569883, -0.25942917693764345, -0.41496029200860923, -0.22790064299734622, 0.0024312017968756774, 0.18125179433388316, 0.31898281350047825]
